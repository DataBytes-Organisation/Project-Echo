# %% [markdown]
# # Introduction to Audio Exploratory Data Analysis
# ## Part 3: Removing Duplicates and training a very simple model
#
# <b> By Daniel Gladman, December 2022 </b>

# %% [markdown]
# In this final part of the exploratory data analysis, I will remove the duplicated data that we identified in the previous part and will do some basic analysis.
#
# I will then quickly demonstrate how to do some quick preprocessing, feature extraction and then train a very simple neural network on this data.
#
# This is not intended to be the final model, nor the final data for this project. You will need to explore this in greater detail on your own.
#
# But this is here to give you a rough idea of what can be done with audio data and how a simple model can be trained.

# %%
# Import all the neccessary libraries
from datetime import datetime
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import librosa
import numpy as np
import os 
import pandas as pd
import tensorflow as tf

# %% [markdown]
# First lets load the metadata and duplicate csv files. We will then use the duplicate dataframe as a filter for the metadata. We will extract all rows which have filenames that do not appear in the duplicated filename column. This will be our final dataframe to include in a model.

# %%
metadata = pd.read_csv("./Data/metadata.csv")
duplicates = pd.read_csv("./Data/duplicates.csv")
duplicates.drop("Unnamed: 0", axis=1, inplace=True)
df = metadata[~metadata.filename.isin(duplicates['filename'])]

# %% [markdown]
# Next, feature extraction. For the project we will likely be using mel-spectrograms as the feature to train the model which I discussed in a previous tutorial.
#
# However I wanted to explore a similarly related feature, Mel-Frequency Cepstral Coefficients, or mfcc.
#
# This is an interesting topic that is too complicated to explain here, but simply put, the mfcc attempts to model elements of human speech including phoneme expression, the shape and length of the vocal tract, and glottal pulses which are the variances in voice quality caused by the folds in the vocal cords.
#
# Because it is a model designed for humans, I wouldn't expect it to work well with animals. However, thinking on it further, while animals do not possess the anatomy to produce phonemes and language, there may be enough similarities our respective biologies that might allow an animal to generalize to a human model. That's what I want to find out in this little tutorial. I don't expect this model to perform well for numerous reasons, but lets kick on. We might be surprised.

# %%
def get_mfcc(filename):
    a, sr = librosa.load(filename, res_type="kaiser_best")
    mfccs_features = librosa.feature.mfcc(y = a, sr = sr, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

def feature_extractor(path, df):
    extracted_features=[]
    
    for idx, row in df.iterrows():
        try:
            filename = os.path.join(os.path.abspath(path), os.path.abspath(path),f"{row['class']}/{row['filename']}")
            class_labels = row['class']
            data = get_mfcc(filename)
            extracted_features.append([data, class_labels])
        except(ValueError):
            class_labels = row['class']
            data = np.nan
            extracted_features.append([data, class_labels])
    return extracted_features

def buildDataset(path, df):
    features = feature_extractor(path, df)
    final_df = pd.DataFrame(features, columns=["mfcc", "label"])
    final_df.dropna(inplace=True)
    return final_df

# %% [markdown]
# The above functions will allow us to extract all the features we need from the filtered dataframe.

# %%
path = './Data/'
f_df = buildDataset(path, df)
# Out:
# c:\Projects\Echo\Bioacoustics-Classification-Tool\venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=0
#   return f(*args, **kwargs)

# %% [markdown]
# Next lets quickly check the composition of files in the dataframe. Do we have uneven classes? Do we have sufficient samples?

# %%
f_df.groupby("label").count()
# Out:
#          mfcc
# label
# bird      191
# cat       193
# chicken    29
# cow        69
# dog       188
# donkey     19
# frog       35
# lion       38
# monkey     22
# sheep      34

# %% [markdown]
# I would argue no. Firstly, there are ten distinct classes in the data. Cats, birds and dogs have nearly 200 samples each, which is not ideal but ok... cows have 69 samples, while the rest have under 40 samples. This isn't going to bode well for train-test split. We will definitely need more data if we wanted to build a worthwhile model.
#
# In any case, lets proceed. I will use keras to build the model. I'm not going to go into too much detail here on the model itself as it is simply to demo this sandbox dataset.

# %%
# extract features and classes
X=np.array(f_df['mfcc'].tolist())
y = np.array(f_df['label'].tolist())

# encode the classes as labels so that we can check the answer after the fact.
labelencoder = LabelEncoder()
y = tf.keras.utils.to_categorical(labelencoder.fit_transform(y))

#Split the data.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=890)

# %%
# Build the model
n_labels = y.shape[1]

model = tf.keras.models.Sequential()

#Layer 1
model.add(tf.keras.layers.Dense(100, input_shape=(40,))) #matches n_mels
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dropout(0.5))

#Layer 2
model.add(tf.keras.layers.Dense(200))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dropout(0.5))

#Layer 3
model.add(tf.keras.layers.Dense(100))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dropout(0.5))

#Layer 4
model.add(tf.keras.layers.Dense(n_labels))
model.add(tf.keras.layers.Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4100
#
#  activation (Activation)     (None, 100)               0
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 200)               20200
#
#  activation_1 (Activation)   (None, 200)               0
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  activation_2 (Activation)   (None, 100)               0
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 10)                1010
#
#  activation_3 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 45,410
# Trainable params: 45,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Train the model
n_epochs = 100
n_batch_size = 32

checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath='./Data/audio_classifcation.hdf5', verbose=1, save_best_only=True)

start = datetime.now()
model.fit(X_train, y_train, batch_size=n_batch_size, epochs=n_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer])
duration = datetime.now() - start
print("Training time = ", duration)
# Out:
# Epoch 1/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5481 - accuracy: 0.7812
# Epoch 1: val_loss improved from inf to 0.97783, saving model to ./Data\audio_classifcation.hdf5
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4656 - accuracy: 0.8217 - val_loss: 0.9778 - val_accuracy: 0.7520
# Epoch 2/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.6193 - accuracy: 0.8125
# Epoch 2: val_loss did not improve from 0.97783
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4337 - accuracy: 0.8654 - val_loss: 0.9893 - val_accuracy: 0.7602
# Epoch 3/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.8348 - accuracy: 0.7500
# Epoch 3: val_loss improved from 0.97783 to 0.92498, saving model to ./Data\audio_classifcation.hdf5
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4554 - accuracy: 0.8339 - val_loss: 0.9250 - val_accuracy: 0.7602
# Epoch 4/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.8169 - accuracy: 0.8438
# Epoch 4: val_loss improved from 0.92498 to 0.91638, saving model to ./Data\audio_classifcation.hdf5
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5064 - accuracy: 0.8531 - val_loss: 0.9164 - val_accuracy: 0.7683
# Epoch 5/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3521 - accuracy: 0.8438
# Epoch 5: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4617 - accuracy: 0.8339 - val_loss: 0.9742 - val_accuracy: 0.7480
# Epoch 6/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2503 - accuracy: 0.9062
# Epoch 6: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.8252 - val_loss: 1.0209 - val_accuracy: 0.7317
# Epoch 7/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3575 - accuracy: 0.8438
# Epoch 7: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4753 - accuracy: 0.8322 - val_loss: 1.0145 - val_accuracy: 0.7561
# Epoch 8/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5569 - accuracy: 0.8125
# Epoch 8: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4269 - accuracy: 0.8549 - val_loss: 1.0297 - val_accuracy: 0.7602
# Epoch 9/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2818 - accuracy: 0.8750
# Epoch 9: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4402 - accuracy: 0.8636 - val_loss: 1.0184 - val_accuracy: 0.7602
# Epoch 10/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1646 - accuracy: 0.9375
# Epoch 10: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4757 - accuracy: 0.8462 - val_loss: 1.0429 - val_accuracy: 0.7520
# Epoch 11/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2407 - accuracy: 0.9375
# Epoch 11: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4112 - accuracy: 0.8497 - val_loss: 1.0778 - val_accuracy: 0.7520
# Epoch 12/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3915 - accuracy: 0.9062
# Epoch 12: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4461 - accuracy: 0.8497 - val_loss: 1.1001 - val_accuracy: 0.7520
# Epoch 13/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4058 - accuracy: 0.8125
# Epoch 13: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4517 - accuracy: 0.8392 - val_loss: 1.0316 - val_accuracy: 0.7520
# Epoch 14/100
# 18/18 [==============================] - ETA: 0s - loss: 0.4863 - accuracy: 0.8304
# Epoch 14: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4863 - accuracy: 0.8304 - val_loss: 0.9913 - val_accuracy: 0.7561
# Epoch 15/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.6117 - accuracy: 0.8125
# Epoch 15: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4476 - accuracy: 0.8549 - val_loss: 1.0569 - val_accuracy: 0.7480
# Epoch 16/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2577 - accuracy: 0.9062
# Epoch 16: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3844 - accuracy: 0.8724 - val_loss: 1.1282 - val_accuracy: 0.7439
# Epoch 17/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.6085 - accuracy: 0.7188
# Epoch 17: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4672 - accuracy: 0.8252 - val_loss: 1.1574 - val_accuracy: 0.7317
# Epoch 18/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4383 - accuracy: 0.7500
# Epoch 18: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4234 - accuracy: 0.8427 - val_loss: 1.0908 - val_accuracy: 0.7480
# Epoch 19/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3538 - accuracy: 0.8750
# Epoch 19: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.8549 - val_loss: 1.1035 - val_accuracy: 0.7520
# Epoch 20/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.6204 - accuracy: 0.7188
# Epoch 20: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4591 - accuracy: 0.8304 - val_loss: 1.1619 - val_accuracy: 0.7480
# Epoch 21/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5100 - accuracy: 0.8125
# Epoch 21: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4995 - accuracy: 0.8374 - val_loss: 1.1171 - val_accuracy: 0.7642
# Epoch 22/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5164 - accuracy: 0.7812
# Epoch 22: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4306 - accuracy: 0.8374 - val_loss: 1.1106 - val_accuracy: 0.7398
# Epoch 23/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2767 - accuracy: 0.8750
# Epoch 23: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3718 - accuracy: 0.8706 - val_loss: 1.1086 - val_accuracy: 0.7398
# Epoch 24/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5945 - accuracy: 0.8125
# Epoch 24: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3902 - accuracy: 0.8706 - val_loss: 1.1676 - val_accuracy: 0.7358
# Epoch 25/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3320 - accuracy: 0.8438
# Epoch 25: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4016 - accuracy: 0.8671 - val_loss: 1.1878 - val_accuracy: 0.7561
# Epoch 26/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.9393 - accuracy: 0.7812
# Epoch 26: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4480 - accuracy: 0.8654 - val_loss: 1.2015 - val_accuracy: 0.7520
# Epoch 27/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2688 - accuracy: 0.8438
# Epoch 27: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4213 - accuracy: 0.8531 - val_loss: 1.1337 - val_accuracy: 0.7398
# Epoch 28/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5490 - accuracy: 0.8750
# Epoch 28: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4083 - accuracy: 0.8741 - val_loss: 1.0410 - val_accuracy: 0.7520
# Epoch 29/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2170 - accuracy: 0.9062
# Epoch 29: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3643 - accuracy: 0.8881 - val_loss: 1.0357 - val_accuracy: 0.7520
# Epoch 30/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1091 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3996 - accuracy: 0.8689 - val_loss: 1.0977 - val_accuracy: 0.7358
# Epoch 31/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1574 - accuracy: 0.9375
# Epoch 31: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4017 - accuracy: 0.8584 - val_loss: 1.1611 - val_accuracy: 0.7358
# Epoch 32/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4187 - accuracy: 0.8438
# Epoch 32: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4308 - accuracy: 0.8531 - val_loss: 1.1414 - val_accuracy: 0.7602
# Epoch 33/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3316 - accuracy: 0.8438
# Epoch 33: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3851 - accuracy: 0.8671 - val_loss: 1.1716 - val_accuracy: 0.7358
# Epoch 34/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1835 - accuracy: 0.9688
# Epoch 34: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4293 - accuracy: 0.8601 - val_loss: 1.1962 - val_accuracy: 0.7358
# Epoch 35/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4771 - accuracy: 0.8125
# Epoch 35: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4085 - accuracy: 0.8724 - val_loss: 1.1719 - val_accuracy: 0.7398
# Epoch 36/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5609 - accuracy: 0.7812
# Epoch 36: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4323 - accuracy: 0.8392 - val_loss: 1.1635 - val_accuracy: 0.7480
# Epoch 37/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4108 - accuracy: 0.7812
# Epoch 37: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3547 - accuracy: 0.8741 - val_loss: 1.1305 - val_accuracy: 0.7398
# Epoch 38/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.8437 - accuracy: 0.7500
# Epoch 38: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.8462 - val_loss: 1.1352 - val_accuracy: 0.7276
# Epoch 39/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2182 - accuracy: 0.9375
# Epoch 39: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3995 - accuracy: 0.8566 - val_loss: 1.1481 - val_accuracy: 0.7439
# Epoch 40/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4696 - accuracy: 0.8125
# Epoch 40: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4140 - accuracy: 0.8619 - val_loss: 1.1573 - val_accuracy: 0.7236
# Epoch 41/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5115 - accuracy: 0.8438
# Epoch 41: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4190 - accuracy: 0.8619 - val_loss: 1.1382 - val_accuracy: 0.7317
# Epoch 42/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4403 - accuracy: 0.8438
# Epoch 42: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4065 - accuracy: 0.8584 - val_loss: 1.1206 - val_accuracy: 0.7602
# Epoch 43/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3281 - accuracy: 0.8750
# Epoch 43: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4038 - accuracy: 0.8549 - val_loss: 1.0962 - val_accuracy: 0.7602
# Epoch 44/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1850 - accuracy: 0.9375
# Epoch 44: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3851 - accuracy: 0.8759 - val_loss: 1.1185 - val_accuracy: 0.7480
# Epoch 45/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.6846 - accuracy: 0.7812
# Epoch 45: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4424 - accuracy: 0.8636 - val_loss: 1.1444 - val_accuracy: 0.7642
# Epoch 46/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2120 - accuracy: 0.9375
# Epoch 46: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4381 - accuracy: 0.8601 - val_loss: 1.1645 - val_accuracy: 0.7520
# Epoch 47/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4215 - accuracy: 0.9375
# Epoch 47: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4269 - accuracy: 0.8549 - val_loss: 1.1199 - val_accuracy: 0.7439
# Epoch 48/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4168 - accuracy: 0.8750
# Epoch 48: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3612 - accuracy: 0.8934 - val_loss: 1.2040 - val_accuracy: 0.7317
# Epoch 49/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2762 - accuracy: 0.9062
# Epoch 49: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3800 - accuracy: 0.8566 - val_loss: 1.2491 - val_accuracy: 0.7236
# Epoch 50/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5664 - accuracy: 0.7500
# Epoch 50: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3884 - accuracy: 0.8759 - val_loss: 1.2829 - val_accuracy: 0.7317
# Epoch 51/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3191 - accuracy: 0.8438
# Epoch 51: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3686 - accuracy: 0.8671 - val_loss: 1.2638 - val_accuracy: 0.7520
# Epoch 52/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4101 - accuracy: 0.8438
# Epoch 52: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3751 - accuracy: 0.8759 - val_loss: 1.1886 - val_accuracy: 0.7358
# Epoch 53/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2696 - accuracy: 0.9062
# Epoch 53: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3750 - accuracy: 0.8724 - val_loss: 1.2507 - val_accuracy: 0.7561
# Epoch 54/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3366 - accuracy: 0.8750
# Epoch 54: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4519 - accuracy: 0.8444 - val_loss: 1.2369 - val_accuracy: 0.7520
# Epoch 55/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.0771 - accuracy: 1.0000
# Epoch 55: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3922 - accuracy: 0.8776 - val_loss: 1.1404 - val_accuracy: 0.7602
# Epoch 56/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3922 - accuracy: 0.8750
# Epoch 56: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8374 - val_loss: 1.1287 - val_accuracy: 0.7724
# Epoch 57/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4476 - accuracy: 0.8438
# Epoch 57: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3778 - accuracy: 0.8864 - val_loss: 1.1964 - val_accuracy: 0.7439
# Epoch 58/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2038 - accuracy: 0.9062
# Epoch 58: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.8601 - val_loss: 1.1391 - val_accuracy: 0.7561
# Epoch 59/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1537 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3842 - accuracy: 0.8846 - val_loss: 1.1462 - val_accuracy: 0.7439
# Epoch 60/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3991 - accuracy: 0.8750
# Epoch 60: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4129 - accuracy: 0.8636 - val_loss: 1.2172 - val_accuracy: 0.7276
# Epoch 61/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2148 - accuracy: 0.9375
# Epoch 61: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4092 - accuracy: 0.8636 - val_loss: 1.2158 - val_accuracy: 0.7358
# Epoch 62/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3185 - accuracy: 0.9375
# Epoch 62: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3474 - accuracy: 0.8864 - val_loss: 1.1775 - val_accuracy: 0.7480
# Epoch 63/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2911 - accuracy: 0.9688
# Epoch 63: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3350 - accuracy: 0.8899 - val_loss: 1.1740 - val_accuracy: 0.7520
# Epoch 64/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2188 - accuracy: 0.9062
# Epoch 64: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4011 - accuracy: 0.8776 - val_loss: 1.2012 - val_accuracy: 0.7398
# Epoch 65/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3978 - accuracy: 0.8125
# Epoch 65: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3531 - accuracy: 0.8759 - val_loss: 1.2182 - val_accuracy: 0.7439
# Epoch 66/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3291 - accuracy: 0.9062
# Epoch 66: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3623 - accuracy: 0.8671 - val_loss: 1.2249 - val_accuracy: 0.7317
# Epoch 67/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2679 - accuracy: 0.9062
# Epoch 67: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3871 - accuracy: 0.8899 - val_loss: 1.1372 - val_accuracy: 0.7520
# Epoch 68/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4661 - accuracy: 0.8438
# Epoch 68: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8741 - val_loss: 1.1728 - val_accuracy: 0.7439
# Epoch 69/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3540 - accuracy: 0.8750
# Epoch 69: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3607 - accuracy: 0.8794 - val_loss: 1.2026 - val_accuracy: 0.7358
# Epoch 70/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2178 - accuracy: 0.9375
# Epoch 70: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3520 - accuracy: 0.8881 - val_loss: 1.1701 - val_accuracy: 0.7439
# Epoch 71/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5525 - accuracy: 0.8750
# Epoch 71: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3955 - accuracy: 0.8654 - val_loss: 1.2080 - val_accuracy: 0.7439
# Epoch 72/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1507 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3771 - accuracy: 0.8899 - val_loss: 1.2488 - val_accuracy: 0.7480
# Epoch 73/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2884 - accuracy: 0.9062
# Epoch 73: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.8829 - val_loss: 1.2538 - val_accuracy: 0.7398
# Epoch 74/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3739 - accuracy: 0.8750
# Epoch 74: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.8811 - val_loss: 1.1882 - val_accuracy: 0.7439
# Epoch 75/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4308 - accuracy: 0.7812
# Epoch 75: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3080 - accuracy: 0.9021 - val_loss: 1.2208 - val_accuracy: 0.7480
# Epoch 76/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.7544 - accuracy: 0.7812
# Epoch 76: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8864 - val_loss: 1.2513 - val_accuracy: 0.7439
# Epoch 77/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5539 - accuracy: 0.8125
# Epoch 77: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3879 - accuracy: 0.8689 - val_loss: 1.1733 - val_accuracy: 0.7439
# Epoch 78/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4256 - accuracy: 0.8438
# Epoch 78: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3777 - accuracy: 0.8671 - val_loss: 1.1556 - val_accuracy: 0.7480
# Epoch 79/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3891 - accuracy: 0.9375
# Epoch 79: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4151 - accuracy: 0.8654 - val_loss: 1.1722 - val_accuracy: 0.7358
# Epoch 80/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4737 - accuracy: 0.7812
# Epoch 80: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3838 - accuracy: 0.8776 - val_loss: 1.2004 - val_accuracy: 0.7358
# Epoch 81/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4048 - accuracy: 0.8750
# Epoch 81: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3465 - accuracy: 0.8846 - val_loss: 1.2204 - val_accuracy: 0.7439
# Epoch 82/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.6373 - accuracy: 0.8438
# Epoch 82: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3873 - accuracy: 0.8846 - val_loss: 1.1887 - val_accuracy: 0.7439
# Epoch 83/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3624 - accuracy: 0.9062
# Epoch 83: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3996 - accuracy: 0.8671 - val_loss: 1.1499 - val_accuracy: 0.7480
# Epoch 84/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.6939 - accuracy: 0.7500
# Epoch 84: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3692 - accuracy: 0.8794 - val_loss: 1.1367 - val_accuracy: 0.7480
# Epoch 85/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3164 - accuracy: 0.9375
# Epoch 85: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3386 - accuracy: 0.8741 - val_loss: 1.1944 - val_accuracy: 0.7480
# Epoch 86/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2019 - accuracy: 0.9688
# Epoch 86: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3544 - accuracy: 0.8846 - val_loss: 1.2647 - val_accuracy: 0.7358
# Epoch 87/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1230 - accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2998 - accuracy: 0.8986 - val_loss: 1.3081 - val_accuracy: 0.7520
# Epoch 88/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1972 - accuracy: 0.9375
# Epoch 88: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3472 - accuracy: 0.8846 - val_loss: 1.3074 - val_accuracy: 0.7398
# Epoch 89/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2081 - accuracy: 0.9062
# Epoch 89: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3475 - accuracy: 0.8846 - val_loss: 1.2983 - val_accuracy: 0.7520
# Epoch 90/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5254 - accuracy: 0.7812
# Epoch 90: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3419 - accuracy: 0.8916 - val_loss: 1.3564 - val_accuracy: 0.7236
# Epoch 91/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2375 - accuracy: 0.9375
# Epoch 91: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3371 - accuracy: 0.8934 - val_loss: 1.3007 - val_accuracy: 0.7358
# Epoch 92/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.1385 - accuracy: 0.9688
# Epoch 92: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3323 - accuracy: 0.8899 - val_loss: 1.3114 - val_accuracy: 0.7398
# Epoch 93/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3906 - accuracy: 0.9062
# Epoch 93: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3285 - accuracy: 0.8776 - val_loss: 1.3527 - val_accuracy: 0.7520
# Epoch 94/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5208 - accuracy: 0.7812
# Epoch 94: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3248 - accuracy: 0.8846 - val_loss: 1.2925 - val_accuracy: 0.7602
# Epoch 95/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.3028 - accuracy: 0.8750
# Epoch 95: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3978 - accuracy: 0.8724 - val_loss: 1.3345 - val_accuracy: 0.7520
# Epoch 96/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.4513 - accuracy: 0.8750
# Epoch 96: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3230 - accuracy: 0.8951 - val_loss: 1.2634 - val_accuracy: 0.7520
# Epoch 97/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.7316 - accuracy: 0.7812
# Epoch 97: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4127 - accuracy: 0.8689 - val_loss: 1.2006 - val_accuracy: 0.7398
# Epoch 98/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5001 - accuracy: 0.7812
# Epoch 98: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3956 - accuracy: 0.8741 - val_loss: 1.1909 - val_accuracy: 0.7561
# Epoch 99/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.2531 - accuracy: 0.9375
# Epoch 99: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3300 - accuracy: 0.8899 - val_loss: 1.1967 - val_accuracy: 0.7480
# Epoch 100/100
#  1/18 [>.............................] - ETA: 0s - loss: 0.5833 - accuracy: 0.8125
# Epoch 100: val_loss did not improve from 0.91638
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3786 - accuracy: 0.8916 - val_loss: 1.2911 - val_accuracy: 0.7480
# Training time =  0:00:05.805754

# %%
test_accuracy=model.evaluate(X_test, y_test, verbose=0)
print(f'The test accuracy was: {round(test_accuracy[1]*100,4)}%')
# Out:
# The test accuracy was: 75.2033%

# %% [markdown]
# You are able to go back and rerun the previous blocks to see if the accuracy can be further improved over a few more generations. Because the dataset is small, it won't take long.
#
# When I ran it on my system, the first generation was about 58% accurate, the second generation was about 68% accurate, third about 75% accurate, and the fourth not improving much from there.
#
# Not bad for such a small dataset with 10 classes right? Well, lets test it on something it hasn't seen.
#
# Because I don't have any additional animal noises that the model hasn't seen, I cannot really test it on proper animal sounds. In hindsight, while writing this I probably should have randomly extracted one of two audio files from each class and held them seperately from the model.
#
# Instead, because it amuses me so, I will attempt to make som animal noises myself and see how well the model classifies them.

# %%
test_file = "./human_cat.wav"
pred_mfcc = get_mfcc(test_file)
pred_mfcc = pred_mfcc.reshape(1,-1)

prediction = model.predict(pred_mfcc)

result = np.argmax(prediction, axis=1)
result = labelencoder.inverse_transform(result)

result
# Out:
# 1/1 [==============================] - 0s 61ms/step
# array(['cat'], dtype='<U7')

# %% [markdown]
# That's good, it seems like I can make a cat noise.

# %%
test_file = "./human_donkey.wav"
pred_mfcc = get_mfcc(test_file)
pred_mfcc = pred_mfcc.reshape(1,-1)

prediction = model.predict(pred_mfcc)

result = np.argmax(prediction, axis=1)
result = labelencoder.inverse_transform(result)

result
# Out:
# 1/1 [==============================] - 0s 15ms/step
# array(['cat'], dtype='<U7')

# %% [markdown]
# Hmmm, my donkey seems more like a cat to this model.

# %%
test_file = "./human_cow.wav"
pred_mfcc = get_mfcc(test_file)
pred_mfcc = pred_mfcc.reshape(1,-1)

prediction = model.predict(pred_mfcc)

result = np.argmax(prediction, axis=1)
result = labelencoder.inverse_transform(result)

result
# Out:
# 1/1 [==============================] - 0s 15ms/step
# array(['cat'], dtype='<U7')

# %% [markdown]
# And my cow seems more like a cat to this model.
#
# Now, depending on how many generations you train the model, you will find that the results will change. Right now, four generations isn't enough for the model to really learn. Infact it is probably naively selecting 'cat' because there is such a large imbalance in the samples among classes.
#
# Again, the point of this was not to show you an excellent model. Moreover, there isn't really any expectation that a model trained on animal noises could guess a human mimicking these animals. The point here was to illustrate how important having good quality data is to training a model.
#
# Now, if you wish, you can rewrite this code to extract some animal sounds from the data, exclude them from train-test, and see if the model performs any better.
#
# Or, you can go out, find some high quality data and contribute to the project goals.
