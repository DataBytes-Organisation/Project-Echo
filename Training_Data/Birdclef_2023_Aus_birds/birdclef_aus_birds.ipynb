# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("train_metadata.csv")
df.head()
# Out:
#   primary_label secondary_labels              type  latitude  longitude  \
# 0       abethr1               []          ['song']    4.3906    38.2788
# 1       abethr1               []          ['call']   -2.9524    38.2921
# 2       abethr1               []          ['song']   -2.9524    38.2921
# 3       abethr1               []          ['song']   -2.9524    38.2921
# 4       abethr1               []  ['call', 'song']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.5
#
#                                  url              filename
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg
# 2  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg
# 3  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg
# 4  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg

# %% [markdown]
# The train_medata.csv is the information of all the bird sounds in the birdclef database the following dataset contains various aspects such as:
# 1. primary_label - The label of the sound files.
# 2. secondary_label - A secondary label of the sound files.
# 3. type - The type of the sound
# 4. latitude - The latitude of where the bird sound was collected.
# 5. longitude - The longitude of where the bird sound was collected.
# 6. scientific_name - The scientific name of the bird species.
# 7. common_name - The common name of the bird species.
# 8. author - the author for the file.
# 9. licence - the licence for the audio file.
# 10. rating - the rating for the file.
# 11. url - the url for the sound.
# 12. filename - the name of the audio file.
#
# To further process this data and to find if the whole dataset contains any Australian birds we can use the latitude and longitudes to pinpoint Australian locations.
#
# Australia is roughly bounded by the following latitudinal and longitudinal coordinates:
#
# Latitude: -10 to -44
# Longitude: 113 to 154

# %%
# Defining the boundaries for Australia

latitude_bounds = (-44, -10)
longitude_bounds = (113, 154)

# %%
# Filtering the dataset 

australian_birds = df[
    (df['latitude'].between(latitude_bounds[0], latitude_bounds[1])) &
    (df['longitude'].between(longitude_bounds[0], longitude_bounds[1]))
]

australian_birds_count = australian_birds.shape[0]
australian_birds_count
# Out:
# 20

# %%
australian_birds
# Out:
#       primary_label secondary_labels                                  type  \
# 1896        blakit1               []                       ['flight call']
# 2089        blakit1               []                                  ['']
# 3241         categr               []                              ['call']
# 3267         categr               []                              ['call']
# 3299         categr               []                              ['call']
# 7801         grecor               []                              ['call']
# 7834         grecor               []  ['begging call', 'call', 'juvenile']
# 7974         greegr               []                              ['call']
# 8023         greegr               []                              ['call']
# 8035         greegr               []               ['call', 'flight call']
# 8163         greegr               []                       ['flight call']
# 8807         helgui               []                              ['call']
# 8828         helgui               []                              ['call']
# 8841         helgui               []                              ['call']
# 9522        laudov1               []                         ['uncertain']
# 9702         litegr               []                              ['call']
# 12036       rerswa1               []                              ['song']
# 13308        strher               []                              ['call']
# 13345        strher               []                ['alarm call', 'call']
# 13390        strher               []                         ['uncertain']
#
#        latitude  longitude            scientific_name          common_name  \
# 1896   -38.0051   144.5904             Milvus migrans           Black Kite
# 2089   -12.3606   130.8701             Milvus migrans           Black Kite
# 3241   -28.2119   153.5210              Bubulcus ibis         Cattle Egret
# 3267   -38.1169   147.0749              Bubulcus ibis         Cattle Egret
# 3299   -26.7629   152.8483              Bubulcus ibis         Cattle Egret
# 7801   -36.9423   149.9063        Phalacrocorax carbo      Great Cormorant
# 7834   -33.8985   151.2327        Phalacrocorax carbo      Great Cormorant
# 7974   -38.0051   144.5904                 Ardea alba          Great Egret
# 8023   -34.7561   142.3439                 Ardea alba          Great Egret
# 8035   -33.5608   150.8196                 Ardea alba          Great Egret
# 8163   -12.7945   143.3212                 Ardea alba          Great Egret
# 8807   -17.1553   144.5243           Numida meleagris  Helmeted Guineafowl
# 8828   -27.2680   152.8600           Numida meleagris  Helmeted Guineafowl
# 8841   -36.1460   144.7448           Numida meleagris  Helmeted Guineafowl
# 9522   -31.9225   115.8333  Streptopelia senegalensis        Laughing Dove
# 9702   -17.9753   122.3447           Egretta garzetta         Little Egret
# 12036  -16.4430   145.3782           Cecropis daurica   Red-rumped Swallow
# 13308  -28.1949   153.5512          Butorides striata       Striated Heron
# 13345  -33.9454   151.1573          Butorides striata       Striated Heron
# 13390  -28.1956   153.5514          Butorides striata       Striated Heron
#
#                author                                            license  \
# 1896      nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 2089      nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 3241      nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 3267      nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 3299   Greg McLachlan  Creative Commons Attribution-NonCommercial-Sha...
# 7801      nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 7834   Greg McLachlan  Creative Commons Attribution-NonCommercial-Sha...
# 7974      nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 8023      nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 8035   Greg McLachlan  Creative Commons Attribution-NonCommercial-Sha...
# 8163     Phil Gregory  Creative Commons Attribution-NonCommercial-Sha...
# 8807     Adrian Walsh  Creative Commons Attribution-NonCommercial-Sha...
# 8828   Greg McLachlan  Creative Commons Attribution-NonCommercial-Sha...
# 8841      nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 9522     Drew Davison  Creative Commons Attribution-NonCommercial-Sha...
# 9702    Nigel Jackett  Creative Commons Attribution-NonCommercial-Sha...
# 12036     Tom Tarrant  Creative Commons Attribution-NonCommercial-Sha...
# 13308     nick talbot  Creative Commons Attribution-NonCommercial-Sha...
# 13345  Greg McLachlan  Creative Commons Attribution-NonCommercial-Sha...
# 13390     nick talbot  Creative Commons Attribution-NonCommercial-Sha...
#
#        rating                                url              filename
# 1896      2.5  https://www.xeno-canto.org/290067  blakit1/XC290067.ogg
# 2089      4.5      https://xeno-canto.org/740444  blakit1/XC740444.ogg
# 3241      3.5  https://www.xeno-canto.org/210378   categr/XC210378.ogg
# 3267      3.0  https://www.xeno-canto.org/321214   categr/XC321214.ogg
# 3299      3.5  https://www.xeno-canto.org/393573   categr/XC393573.ogg
# 7801      2.5  https://www.xeno-canto.org/182031   grecor/XC182031.ogg
# 7834      5.0  https://www.xeno-canto.org/381459   grecor/XC381459.ogg
# 7974      4.0  https://www.xeno-canto.org/188602   greegr/XC188602.ogg
# 8023      3.0  https://www.xeno-canto.org/331744   greegr/XC331744.ogg
# 8035      4.5  https://www.xeno-canto.org/365950   greegr/XC365950.ogg
# 8163      4.0       http://xeno-canto.org/692235   greegr/XC692235.ogg
# 8807      4.0  https://www.xeno-canto.org/165726   helgui/XC165726.ogg
# 8828      3.5  https://www.xeno-canto.org/394468   helgui/XC394468.ogg
# 8841      4.0  https://www.xeno-canto.org/574813   helgui/XC574813.ogg
# 9522      4.0  https://www.xeno-canto.org/588096  laudov1/XC588096.ogg
# 9702      5.0  https://www.xeno-canto.org/236290   litegr/XC236290.ogg
# 12036     4.0  https://www.xeno-canto.org/502701  rerswa1/XC502701.ogg
# 13308     4.0  https://www.xeno-canto.org/210507   strher/XC210507.ogg
# 13345     3.5  https://www.xeno-canto.org/354401   strher/XC354401.ogg
# 13390     3.5  https://www.xeno-canto.org/659999   strher/XC659999.ogg

# %% [markdown]
# Found 20 entries within the dataset containing sounds of birds such as Black Kite, Striated Heron, Laughing Dove, Little Egret and many more and various types such as flight call, call, alarm call, begging call etc.

# %%
# Converting the file to dataset

australian_birds.to_csv('australian_birds.csv')
