# %%
pip install FuzzyTM
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: FuzzyTM in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.0.9)
# Requirement already satisfied: numpy in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from FuzzyTM) (1.26.4)
# Requirement already satisfied: pandas in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from FuzzyTM) (2.2.2)
# Requirement already satisfied: scipy in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from FuzzyTM) (1.13.0)
# Requirement already satisfied: pyfume in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from FuzzyTM) (0.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->FuzzyTM) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->FuzzyTM) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->FuzzyTM) (2024.1)
# Requirement already satisfied: simpful in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyfume->FuzzyTM) (2.12.0)
# Requirement already satisfied: fst-pso in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyfume->FuzzyTM) (1.8.1)
# Requirement already satisfied: typing-extensions in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyfume->FuzzyTM) (4.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM) (1.16.0)
# Requirement already satisfied: miniful in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fst-pso->pyfume->FuzzyTM) (0.0.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gensim) (1.13.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.13.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user --upgrade scipy
# Out:
# Requirement already satisfied: scipy in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.13.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydub in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.25.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: librosa in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.10.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.13.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (0.59.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.0.8)
# Requirement already satisfied: packaging in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from lazy-loader>=0.1->librosa) (24.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pooch>=1.1->librosa) (4.2.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install librosa pydub soundfile audioread
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: librosa in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.10.2)
# Requirement already satisfied: pydub in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.25.1)
# Requirement already satisfied: soundfile in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.12.1)
# Requirement already satisfied: audioread in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.13.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (0.59.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from librosa) (1.0.8)
# Requirement already satisfied: cffi>=1.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from soundfile) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from lazy-loader>=0.1->librosa) (24.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pooch>=1.1->librosa) (4.2.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\awakw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display as ipd
import scipy.signal
import os
from scipy.io import wavfile


from pydub import AudioSegment
from pydub.utils import mediainfo

# %%
# Function to read audio files from a folder named Read_Audio
def read_audio_from_folder(Read_Audio):
    audio_data = []
    for file_name in os.listdir(Read_Audio):
        file_path = os.path.join(Read_Audio, file_name)
        if os.path.isfile(file_path) and file_name.endswith('.wav'):
            audio, sr = librosa.load(file_path, sr=None)  # Load audio file
            audio_data.append((audio, sr))
    return audio_data

# %%
import scipy.signal

def filter_audio(audio_data, cutoff_freq=2000, filter_type='lowpass'):
    filtered_audio_data = []
    for audio, sr in audio_data:
        # Apply filtering
        if filter_type == 'lowpass':
            nyquist = sr / 2
            cutoff_normal = cutoff_freq / nyquist
            b, a = scipy.signal.butter(6, cutoff_normal, btype='low')
            filtered_audio = scipy.signal.filtfilt(b, a, audio)
        elif filter_type == 'highpass':
            nyquist = sr / 2
            cutoff_normal = cutoff_freq / nyquist
            b, a = scipy.signal.butter(6, cutoff_normal, btype='high')
            filtered_audio = scipy.signal.filtfilt(b, a, audio)
        else:
            raise ValueError("Unsupported filter type. Supported types: 'lowpass', 'highpass'")
        filtered_audio_data.append((filtered_audio, sr))
    return filtered_audio_data

# %%
# Function to save filtered audio to new files
        
def save_filtered_audio(filtered_audio_data, Filtered_Audio):
    for i, (audio, sr) in enumerate(filtered_audio_data):
        output_path = os.path.join(Filtered_Audio, f'filtered_audio_{i}.wav')
        wavfile.write(output_path, sr, audio)

# %%
# Example usage

Read_Audio = r'C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy'
Filtered_Audio = r'C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy'

# %%
# Example to check read and write permissions
def check_permissions(path):
    print("Read permission on", path, ":", os.access(path, os.R_OK))
    print("Write permission on", path, ":", os.access(path, os.W_OK))

check_permissions(Read_Audio)
check_permissions(Filtered_Audio)
# Out:
# Read permission on C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy : True
# Write permission on C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy : True
# Read permission on C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy : True
# Write permission on C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy : True

# %%
import os
import pandas as pd

Read_Audio = r'C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy' 
filtered_audio = r'C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy'

def check_directory(path):
    if os.path.exists(path):
        files = os.listdir(path)
        df = pd.DataFrame(files, columns=['File Name'])
        print("Files in", path, "directory:")
        print(df)
        print("Count of files in", path, ":", len(files))
    else:
        print(path, "directory does not exist.")

# Check the specified directories
check_directory(Read_Audio)
check_directory(Filtered_Audio)
# Out:
# Files in C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy directory:
#              File Name
# 0        Windy (1).wav
# 1       Windy (10).wav
# 2      Windy (100).wav
# 3     Windy (1000).wav
# 4     Windy (1001).wav
# ...                ...
# 2687   Windy (995).wav
# 2688   Windy (996).wav
# 2689   Windy (997).wav
# 2690   Windy (998).wav
# 2691   Windy (999).wav
#
# [2692 rows x 1 columns]
# Count of files in C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy : 2692
# Files in C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy directory:
# Empty DataFrame
# Columns: [File Name]
# Index: []
# Count of files in C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy : 0

# %%
import os

Read_Audio = r'C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy'
filtered_audio = r'C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy'

# Function to check the directory and print details
def check_directory(path):
    if os.path.exists(path):
        files = os.listdir(path)
        print("Files in", path, "directory:", files)
        print("Count of files in", path, ":", len(files))
    else:
        print(path, "directory does not exist.")

# Check the specified directories
check_directory(Read_Audio)
check_directory(Filtered_Audio)
# Out:
# Files in C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy directory: ['Windy (1).wav', 'Windy (10).wav', 'Windy (100).wav', 'Windy (1000).wav', 'Windy (1001).wav', 'Windy (1002).wav', 'Windy (1003).wav', 'Windy (1004).wav', 'Windy (1005).wav', 'Windy (1006).wav', 'Windy (1007).wav', 'Windy (1008).wav', 'Windy (1009).wav', 'Windy (101).wav', 'Windy (1010).wav', 'Windy (1011).wav', 'Windy (1012).wav', 'Windy (1013).wav', 'Windy (1014).wav', 'Windy (1015).wav', 'Windy (1016).wav', 'Windy (1017).wav', 'Windy (1018).wav', 'Windy (1019).wav', 'Windy (102).wav', 'Windy (1020).wav', 'Windy (1021).wav', 'Windy (1022).wav', 'Windy (1023).wav', 'Windy (1024).wav', 'Windy (1025).wav', 'Windy (1026).wav', 'Windy (1027).wav', 'Windy (1028).wav', 'Windy (1029).wav', 'Windy (103).wav', 'Windy (1030).wav', 'Windy (1031).wav', 'Windy (1032).wav', 'Windy (1033).wav', 'Windy (1034).wav', 'Windy (1035).wav', 'Windy (1036).wav', 'Windy (1037).wav', 'Windy (1038).wav', 'Windy (1039).wav', 'Windy (104).wav', 'Windy (1040).wav', 'Windy (1041).wav', 'Windy (1042).wav', 'Windy (1043).wav', 'Windy (1044).wav', 'Windy (1045).wav', 'Windy (1046).wav', 'Windy (1047).wav', 'Windy (1048).wav', 'Windy (1049).wav', 'Windy (105).wav', 'Windy (1050).wav', 'Windy (1051).wav', 'Windy (1052).wav', 'Windy (1053).wav', 'Windy (1054).wav', 'Windy (1055).wav', 'Windy (1056).wav', 'Windy (1057).wav', 'Windy (1058).wav', 'Windy (1059).wav', 'Windy (106).wav', 'Windy (1060).wav', 'Windy (1061).wav', 'Windy (1062).wav', 'Windy (1063).wav', 'Windy (1064).wav', 'Windy (1065).wav', 'Windy (1066).wav', 'Windy (1067).wav', 'Windy (1068).wav', 'Windy (1069).wav', 'Windy (107).wav', 'Windy (1070).wav', 'Windy (1071).wav', 'Windy (1072).wav', 'Windy (1073).wav', 'Windy (1074).wav', 'Windy (1075).wav', 'Windy (1076).wav', 'Windy (1077).wav', 'Windy (1078).wav', 'Windy (1079).wav', 'Windy (108).wav', 'Windy (1080).wav', 'Windy (1081).wav', 'Windy (1082).wav', 'Windy (1083).wav', 'Windy (1084).wav', 'Windy (1085).wav', 'Windy (1086).wav', 'Windy (1087).wav', 'Windy (1088).wav', 'Windy (1089).wav', 'Windy (109).wav', 'Windy (1090).wav', 'Windy (1091).wav', 'Windy (1092).wav', 'Windy (1093).wav', 'Windy (1094).wav', 'Windy (1095).wav', 'Windy (1096).wav', 'Windy (1097).wav', 'Windy (1098).wav', 'Windy (1099).wav', 'Windy (11).wav', 'Windy (110).wav', 'Windy (1100).wav', 'Windy (1101).wav', 'Windy (1102).wav', 'Windy (1103).wav', 'Windy (1104).wav', 'Windy (1105).wav', 'Windy (1106).wav', 'Windy (1107).wav', 'Windy (1108).wav', 'Windy (1109).wav', 'Windy (111).wav', 'Windy (1110).wav', 'Windy (1111).wav', 'Windy (1112).wav', 'Windy (1113).wav', 'Windy (1114).wav', 'Windy (1115).wav', 'Windy (1116).wav', 'Windy (1117).wav', 'Windy (1118).wav', 'Windy (1119).wav', 'Windy (112).wav', 'Windy (1120).wav', 'Windy (1121).wav', 'Windy (1122).wav', 'Windy (1123).wav', 'Windy (1124).wav', 'Windy (1125).wav', 'Windy (1126).wav', 'Windy (1127).wav', 'Windy (1128).wav', 'Windy (1129).wav', 'Windy (113).wav', 'Windy (1130).wav', 'Windy (1131).wav', 'Windy (1132).wav', 'Windy (1133).wav', 'Windy (1134).wav', 'Windy (1135).wav', 'Windy (1136).wav', 'Windy (1137).wav', 'Windy (1138).wav', 'Windy (1139).wav', 'Windy (114).wav', 'Windy (1140).wav', 'Windy (1141).wav', 'Windy (1142).wav', 'Windy (1143).wav', 'Windy (1144).wav', 'Windy (1145).wav', 'Windy (1146).wav', 'Windy (1147).wav', 'Windy (1148).wav', 'Windy (1149).wav', 'Windy (115).wav', 'Windy (1150).wav', 'Windy (1151).wav', 'Windy (1152).wav', 'Windy (1153).wav', 'Windy (1154).wav', 'Windy (1155).wav', 'Windy (1156).wav', 'Windy (1157).wav', 'Windy (1158).wav', 'Windy (1159).wav', 'Windy (116).wav', 'Windy (1160).wav', 'Windy (1161).wav', 'Windy (1162).wav', 'Windy (1163).wav', 'Windy (1164).wav', 'Windy (1165).wav', 'Windy (1166).wav', 'Windy (1167).wav', 'Windy (1168).wav', 'Windy (1169).wav', 'Windy (117).wav', 'Windy (1170).wav', 'Windy (1171).wav', 'Windy (1172).wav', 'Windy (1173).wav', ...
# Count of files in C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Raw\Windy : 2692
# Files in C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy directory: []
# Count of files in C:\Users\awakw\OneDrive\Desktop\University 23-24\T1_Resurgence\Team Project B\WeatherDetection\Clean\Windy : 0

# %%
# Read audio files from folder
audio_data = read_audio_from_folder(Read_Audio)

# %%
import matplotlib.pyplot as plt
import librosa.display

def visualize_audio_signals(audio_data, duration=5, max_images=50):
    count = 0
    for audio, sr in audio_data:
        if count >= max_images:
            break

        # Take a chunk of the audio (first 'duration' seconds)
        audio_chunk = audio[:int(sr * duration)]

        # Create time axis
        time_axis = librosa.times_like(audio_chunk, sr=sr)

        # Plot the audio signal
        plt.figure(figsize=(10, 4))
        librosa.display.waveshow(audio_chunk, sr=sr, alpha=0.8)
        plt.xlabel("Time (s)")
        plt.ylabel("Amplitude")
        plt.title(f"Audio Signal {count + 1}")
        plt.show()

        count += 1

 #Example usage
# `audio_data` is already defined as a list of tuples with audio and sample rate
visualize_audio_signals(audio_data)

# %%
# Filter audio data (e.g., lowpass filtering with cutoff frequency of 1500 Hz)
filtered_audio_data = filter_audio(audio_data, cutoff_freq=1500, filter_type='lowpass')

# %%
# Save filtered audio to new files
save_filtered_audio(filtered_audio_data, Filtered_Audio)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
