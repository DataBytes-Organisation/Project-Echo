# %%
from google.colab import drive

drive.mount('/content/drive')

import os
import random
import numpy as np
from PIL import Image, ImageEnhance, ImageFilter

# --- ROOT FOLDERS & CONFIG ---
file_path = "/content/drive/MyDrive/BIRDS_DATASET2"   # root with class folders
output_path = "/content/drive/MyDrive/Birds_Dataset3" # root for augmented class folders
target_count_per_class = 500                         # total images per class

os.makedirs(output_path, exist_ok=True)
random.seed(42)
np.random.seed(42)


def random_augment(img):
    """Apply a random sequence of augmentations to a PIL Image (RGB)."""
    w, h = img.size

    # Horizontal flip
    if random.random() < 0.5:
        img = img.transpose(Image.FLIP_LEFT_RIGHT)

    # Small rotation
    if random.random() < 0.5:
        angle = random.uniform(-20, 20)  # degrees
        img = img.rotate(angle, resample=Image.BICUBIC)

    # Random crop & resize back (acts like zoom/translation)
    if random.random() < 0.7:
        scale = random.uniform(0.7, 1.0)  # 0.7 = tighter crop, 1.0 = no crop
        new_w, new_h = int(w * scale), int(h * scale)
        if new_w < w and new_h < h:
            left = random.randint(0, w - new_w)
            top = random.randint(0, h - new_h)
            img = img.crop((left, top, left + new_w, top + new_h))
            img = img.resize((w, h), Image.LANCZOS)

    # Brightness
    if random.random() < 0.7:
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(random.uniform(0.7, 1.3))

    # Contrast
    if random.random() < 0.7:
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(random.uniform(0.7, 1.3))

    # Colour / saturation
    if random.random() < 0.7:
        enhancer = ImageEnhance.Color(img)
        img = enhancer.enhance(random.uniform(0.7, 1.3))

    # Slight blur
    if random.random() < 0.3:
        radius = random.uniform(0.3, 1.0)
        img = img.filter(ImageFilter.GaussianBlur(radius=radius))

    # Add Gaussian noise
    if random.random() < 0.5:
        arr = np.asarray(img).astype("float32")
        noise = np.random.normal(0, 8, arr.shape)  # mean 0, std 8
        arr = arr + noise
        arr = np.clip(arr, 0, 255).astype("uint8")
        img = Image.fromarray(arr)

    return img


def process_class_dir(input_dir, output_dir, target_count):
    """Copy originals and create augmentations for one class folder."""
    image_paths = [
        os.path.join(input_dir, f)
        for f in os.listdir(input_dir)
        if f.lower().endswith((".png", ".jpg", ".jpeg"))
    ]

    if not image_paths:
        print(f"No images found in '{input_dir}', skipping.")
        return

    os.makedirs(output_dir, exist_ok=True)

    class_name = os.path.basename(input_dir)
    print(f"\nProcessing class '{class_name}'")
    print(f"Found {len(image_paths)} base images in '{input_dir}'.")

    idx = 0

    # 1) Copy originals
    for path in image_paths:
        img = Image.open(path).convert("RGB")
        idx += 1
        out_path = os.path.join(output_dir, f"image_{idx:04d}.png")
        img.save(out_path)
    print(f"Copied {idx} original images to '{output_dir}'.")

    # 2) Generate augmentations
    while idx < target_count:
        src_path = random.choice(image_paths)
        img = Image.open(src_path).convert("RGB")
        aug = random_augment(img)

        idx += 1
        out_path = os.path.join(output_dir, f"image_{idx:04d}.png")
        aug.save(out_path)

        if idx % 100 == 0 or idx == target_count:
            print(f"[{class_name}] Created {idx} images so far...")

    print(f"Done '{class_name}'. Saved {idx} images total in '{output_dir}'.")


# --- MAIN: LOOP OVER ALL CLASS FOLDERS ---
class_folders = [
    d for d in sorted(os.listdir(file_path))
    if os.path.isdir(os.path.join(file_path, d))
]

if not class_folders:
    raise RuntimeError(f"No subfolders found in '{file_path}'")

print(f"Found {len(class_folders)} class folders in '{file_path}'.")

for folder_name in class_folders:
    in_dir = os.path.join(file_path, folder_name)
    out_dir = os.path.join(output_path, folder_name)
    process_class_dir(in_dir, out_dir, target_count_per_class)

print("\nAll class folders processed.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 49 class folders in '/content/drive/MyDrive/BIRDS_DATASET2'.
#
# Processing class 'Aythya australi_300x300'
# Found 140 base images in '/content/drive/MyDrive/BIRDS_DATASET2/Aythya australi_300x300'.
# Copied 140 original images to '/content/drive/MyDrive/Birds_Dataset3/Aythya australi_300x300'.
# [Aythya australi_300x300] Created 200 images so far...
# [Aythya australi_300x300] Created 300 images so far...
# [Aythya australi_300x300] Created 400 images so far...
# [Aythya australi_300x300] Created 500 images so far...
# Done 'Aythya australi_300x300'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/Aythya australi_300x300'.
#
# Processing class 'Burhinus grallarius_300x300'
# Found 293 base images in '/content/drive/MyDrive/BIRDS_DATASET2/Burhinus grallarius_300x300'.
# Copied 293 original images to '/content/drive/MyDrive/Birds_Dataset3/Burhinus grallarius_300x300'.
# [Burhinus grallarius_300x300] Created 300 images so far...
# [Burhinus grallarius_300x300] Created 400 images so far...
# [Burhinus grallarius_300x300] Created 500 images so far...
# Done 'Burhinus grallarius_300x300'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/Burhinus grallarius_300x300'.
#
# Processing class 'Eolophus roseicapilla_300x300'
# Found 400 base images in '/content/drive/MyDrive/BIRDS_DATASET2/Eolophus roseicapilla_300x300'.
# Copied 400 original images to '/content/drive/MyDrive/Birds_Dataset3/Eolophus roseicapilla_300x300'.
# [Eolophus roseicapilla_300x300] Created 500 images so far...
# Done 'Eolophus roseicapilla_300x300'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/Eolophus roseicapilla_300x300'.
#
# Processing class 'acanthagenys_rufogularis_300x300a'
# Found 27 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acanthagenys_rufogularis_300x300a'.
# Copied 27 original images to '/content/drive/MyDrive/Birds_Dataset3/acanthagenys_rufogularis_300x300a'.
# [acanthagenys_rufogularis_300x300a] Created 100 images so far...
# [acanthagenys_rufogularis_300x300a] Created 200 images so far...
# [acanthagenys_rufogularis_300x300a] Created 300 images so far...
# [acanthagenys_rufogularis_300x300a] Created 400 images so far...
# [acanthagenys_rufogularis_300x300a] Created 500 images so far...
# Done 'acanthagenys_rufogularis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acanthagenys_rufogularis_300x300a'.
#
# Processing class 'acanthiza_apicalis_300x300a'
# Found 11 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acanthiza_apicalis_300x300a'.
# Copied 11 original images to '/content/drive/MyDrive/Birds_Dataset3/acanthiza_apicalis_300x300a'.
# [acanthiza_apicalis_300x300a] Created 100 images so far...
# [acanthiza_apicalis_300x300a] Created 200 images so far...
# [acanthiza_apicalis_300x300a] Created 300 images so far...
# [acanthiza_apicalis_300x300a] Created 400 images so far...
# [acanthiza_apicalis_300x300a] Created 500 images so far...
# Done 'acanthiza_apicalis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acanthiza_apicalis_300x300a'.
#
# Processing class 'acanthiza_chrysorrhoa_300x300a'
# Found 22 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acanthiza_chrysorrhoa_300x300a'.
# Copied 22 original images to '/content/drive/MyDrive/Birds_Dataset3/acanthiza_chrysorrhoa_300x300a'.
# [acanthiza_chrysorrhoa_300x300a] Created 100 images so far...
# [acanthiza_chrysorrhoa_300x300a] Created 200 images so far...
# [acanthiza_chrysorrhoa_300x300a] Created 300 images so far...
# [acanthiza_chrysorrhoa_300x300a] Created 400 images so far...
# [acanthiza_chrysorrhoa_300x300a] Created 500 images so far...
# Done 'acanthiza_chrysorrhoa_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acanthiza_chrysorrhoa_300x300a'.
#
# Processing class 'acanthiza_lineata_300x300a'
# Found 28 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acanthiza_lineata_300x300a'.
# Copied 28 original images to '/content/drive/MyDrive/Birds_Dataset3/acanthiza_lineata_300x300a'.
# [acanthiza_lineata_300x300a] Created 100 images so far...
# [acanthiza_lineata_300x300a] Created 200 images so far...
# [acanthiza_lineata_300x300a] Created 300 images so far...
# [acanthiza_lineata_300x300a] Created 400 images so far...
# [acanthiza_lineata_300x300a] Created 500 images so far...
# Done 'acanthiza_lineata_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acanthiza_lineata_300x300a'.
#
# Processing class 'acanthiza_nana_300x300a'
# Found 17 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acanthiza_nana_300x300a'.
# Copied 17 original images to '/content/drive/MyDrive/Birds_Dataset3/acanthiza_nana_300x300a'.
# [acanthiza_nana_300x300a] Created 100 images so far...
# [acanthiza_nana_300x300a] Created 200 images so far...
# [acanthiza_nana_300x300a] Created 300 images so far...
# [acanthiza_nana_300x300a] Created 400 images so far...
# [acanthiza_nana_300x300a] Created 500 images so far...
# Done 'acanthiza_nana_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acanthiza_nana_300x300a'.
#
# Processing class 'acanthiza_pusilla_300x300a'
# Found 34 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acanthiza_pusilla_300x300a'.
# Copied 34 original images to '/content/drive/MyDrive/Birds_Dataset3/acanthiza_pusilla_300x300a'.
# [acanthiza_pusilla_300x300a] Created 100 images so far...
# [acanthiza_pusilla_300x300a] Created 200 images so far...
# [acanthiza_pusilla_300x300a] Created 300 images so far...
# [acanthiza_pusilla_300x300a] Created 400 images so far...
# [acanthiza_pusilla_300x300a] Created 500 images so far...
# Done 'acanthiza_pusilla_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acanthiza_pusilla_300x300a'.
#
# Processing class 'acanthiza_uropygialis_300x300a'
# Found 10 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acanthiza_uropygialis_300x300a'.
# Copied 10 original images to '/content/drive/MyDrive/Birds_Dataset3/acanthiza_uropygialis_300x300a'.
# [acanthiza_uropygialis_300x300a] Created 100 images so far...
# [acanthiza_uropygialis_300x300a] Created 200 images so far...
# [acanthiza_uropygialis_300x300a] Created 300 images so far...
# [acanthiza_uropygialis_300x300a] Created 400 images so far...
# [acanthiza_uropygialis_300x300a] Created 500 images so far...
# Done 'acanthiza_uropygialis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acanthiza_uropygialis_300x300a'.
#
# Processing class 'acanthorhynchus_tenuirostris_300x300a'
# Found 55 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acanthorhynchus_tenuirostris_300x300a'.
# Copied 55 original images to '/content/drive/MyDrive/Birds_Dataset3/acanthorhynchus_tenuirostris_300x300a'.
# [acanthorhynchus_tenuirostris_300x300a] Created 100 images so far...
# [acanthorhynchus_tenuirostris_300x300a] Created 200 images so far...
# [acanthorhynchus_tenuirostris_300x300a] Created 300 images so far...
# [acanthorhynchus_tenuirostris_300x300a] Created 400 images so far...
# [acanthorhynchus_tenuirostris_300x300a] Created 500 images so far...
# Done 'acanthorhynchus_tenuirostris_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acanthorhynchus_tenuirostris_300x300a'.
#
# Processing class 'accipiter_cooperi_300x300a'
# Found 5 base images in '/content/drive/MyDrive/BIRDS_DATASET2/accipiter_cooperi_300x300a'.
# Copied 5 original images to '/content/drive/MyDrive/Birds_Dataset3/accipiter_cooperi_300x300a'.
# [accipiter_cooperi_300x300a] Created 100 images so far...
# [accipiter_cooperi_300x300a] Created 200 images so far...
# [accipiter_cooperi_300x300a] Created 300 images so far...
# [accipiter_cooperi_300x300a] Created 400 images so far...
# [accipiter_cooperi_300x300a] Created 500 images so far...
# Done 'accipiter_cooperi_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/accipiter_cooperi_300x300a'.
#
# Processing class 'accipiter_fasciatus_300x300a'
# Found 14 base images in '/content/drive/MyDrive/BIRDS_DATASET2/accipiter_fasciatus_300x300a'.
# Copied 14 original images to '/content/drive/MyDrive/Birds_Dataset3/accipiter_fasciatus_300x300a'.
# [accipiter_fasciatus_300x300a] Created 100 images so far...
# [accipiter_fasciatus_300x300a] Created 200 images so far...
# [accipiter_fasciatus_300x300a] Created 300 images so far...
# [accipiter_fasciatus_300x300a] Created 400 images so far...
# [accipiter_fasciatus_300x300a] Created 500 images so far...
# Done 'accipiter_fasciatus_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/accipiter_fasciatus_300x300a'.
#
# Processing class 'acrocephalus_australis_300x300a'
# Found 24 base images in '/content/drive/MyDrive/BIRDS_DATASET2/acrocephalus_australis_300x300a'.
# Copied 24 original images to '/content/drive/MyDrive/Birds_Dataset3/acrocephalus_australis_300x300a'.
# [acrocephalus_australis_300x300a] Created 100 images so far...
# [acrocephalus_australis_300x300a] Created 200 images so far...
# [acrocephalus_australis_300x300a] Created 300 images so far...
# [acrocephalus_australis_300x300a] Created 400 images so far...
# [acrocephalus_australis_300x300a] Created 500 images so far...
# Done 'acrocephalus_australis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/acrocephalus_australis_300x300a'.
#
# Processing class 'alauda_arvensis_300x300a'
# Found 75 base images in '/content/drive/MyDrive/BIRDS_DATASET2/alauda_arvensis_300x300a'.
# Copied 75 original images to '/content/drive/MyDrive/Birds_Dataset3/alauda_arvensis_300x300a'.
# [alauda_arvensis_300x300a] Created 100 images so far...
# [alauda_arvensis_300x300a] Created 200 images so far...
# [alauda_arvensis_300x300a] Created 300 images so far...
# [alauda_arvensis_300x300a] Created 400 images so far...
# [alauda_arvensis_300x300a] Created 500 images so far...
# Done 'alauda_arvensis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/alauda_arvensis_300x300a'.
#
# Processing class 'alisterus_scapularis_300x300a'
# Found 93 base images in '/content/drive/MyDrive/BIRDS_DATASET2/alisterus_scapularis_300x300a'.
# Copied 93 original images to '/content/drive/MyDrive/Birds_Dataset3/alisterus_scapularis_300x300a'.
# [alisterus_scapularis_300x300a] Created 100 images so far...
# [alisterus_scapularis_300x300a] Created 200 images so far...
# [alisterus_scapularis_300x300a] Created 300 images so far...
# [alisterus_scapularis_300x300a] Created 400 images so far...
# [alisterus_scapularis_300x300a] Created 500 images so far...
# Done 'alisterus_scapularis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/alisterus_scapularis_300x300a'.
#
# Processing class 'anas_superciliosa_300x300a'
# Found 76 base images in '/content/drive/MyDrive/BIRDS_DATASET2/anas_superciliosa_300x300a'.
# Copied 76 original images to '/content/drive/MyDrive/Birds_Dataset3/anas_superciliosa_300x300a'.
# [anas_superciliosa_300x300a] Created 100 images so far...
# [anas_superciliosa_300x300a] Created 200 images so far...
# [anas_superciliosa_300x300a] Created 300 images so far...
# [anas_superciliosa_300x300a] Created 400 images so far...
# [anas_superciliosa_300x300a] Created 500 images so far...
# Done 'anas_superciliosa_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/anas_superciliosa_300x300a'.
#
# Processing class 'anhinga_novaehollandiae_300x300a'
# Found 97 base images in '/content/drive/MyDrive/BIRDS_DATASET2/anhinga_novaehollandiae_300x300a'.
# Copied 97 original images to '/content/drive/MyDrive/Birds_Dataset3/anhinga_novaehollandiae_300x300a'.
# [anhinga_novaehollandiae_300x300a] Created 100 images so far...
# [anhinga_novaehollandiae_300x300a] Created 200 images so far...
# [anhinga_novaehollandiae_300x300a] Created 300 images so far...
# [anhinga_novaehollandiae_300x300a] Created 400 images so far...
# [anhinga_novaehollandiae_300x300a] Created 500 images so far...
# Done 'anhinga_novaehollandiae_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/anhinga_novaehollandiae_300x300a'.
#
# Processing class 'anseranas_semipalmata_300x300a'
# Found 69 base images in '/content/drive/MyDrive/BIRDS_DATASET2/anseranas_semipalmata_300x300a'.
# Copied 69 original images to '/content/drive/MyDrive/Birds_Dataset3/anseranas_semipalmata_300x300a'.
# [anseranas_semipalmata_300x300a] Created 100 images so far...
# [anseranas_semipalmata_300x300a] Created 200 images so far...
# [anseranas_semipalmata_300x300a] Created 300 images so far...
# [anseranas_semipalmata_300x300a] Created 400 images so far...
# [anseranas_semipalmata_300x300a] Created 500 images so far...
# Done 'anseranas_semipalmata_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/anseranas_semipalmata_300x300a'.
#
# Processing class 'anthochaera_carunculata_300x300a'
# Found 68 base images in '/content/drive/MyDrive/BIRDS_DATASET2/anthochaera_carunculata_300x300a'.
# Copied 68 original images to '/content/drive/MyDrive/Birds_Dataset3/anthochaera_carunculata_300x300a'.
# [anthochaera_carunculata_300x300a] Created 100 images so far...
# [anthochaera_carunculata_300x300a] Created 200 images so far...
# [anthochaera_carunculata_300x300a] Created 300 images so far...
# [anthochaera_carunculata_300x300a] Created 400 images so far...
# [anthochaera_carunculata_300x300a] Created 500 images so far...
# Done 'anthochaera_carunculata_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/anthochaera_carunculata_300x300a'.
#
# Processing class 'anthus_novaeseelandiae_300x300a'
# Found 15 base images in '/content/drive/MyDrive/BIRDS_DATASET2/anthus_novaeseelandiae_300x300a'.
# Copied 15 original images to '/content/drive/MyDrive/Birds_Dataset3/anthus_novaeseelandiae_300x300a'.
# [anthus_novaeseelandiae_300x300a] Created 100 images so far...
# [anthus_novaeseelandiae_300x300a] Created 200 images so far...
# [anthus_novaeseelandiae_300x300a] Created 300 images so far...
# [anthus_novaeseelandiae_300x300a] Created 400 images so far...
# [anthus_novaeseelandiae_300x300a] Created 500 images so far...
# Done 'anthus_novaeseelandiae_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/anthus_novaeseelandiae_300x300a'.
#
# Processing class 'antigone_antigone_300x300a'
# Found 75 base images in '/content/drive/MyDrive/BIRDS_DATASET2/antigone_antigone_300x300a'.
# Copied 75 original images to '/content/drive/MyDrive/Birds_Dataset3/antigone_antigone_300x300a'.
# [antigone_antigone_300x300a] Created 100 images so far...
# [antigone_antigone_300x300a] Created 200 images so far...
# [antigone_antigone_300x300a] Created 300 images so far...
# [antigone_antigone_300x300a] Created 400 images so far...
# [antigone_antigone_300x300a] Created 500 images so far...
# Done 'antigone_antigone_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/antigone_antigone_300x300a'.
#
# Processing class 'antigone_rubicunda_300x300a'
# Found 76 base images in '/content/drive/MyDrive/BIRDS_DATASET2/antigone_rubicunda_300x300a'.
# Copied 76 original images to '/content/drive/MyDrive/Birds_Dataset3/antigone_rubicunda_300x300a'.
# [antigone_rubicunda_300x300a] Created 100 images so far...
# [antigone_rubicunda_300x300a] Created 200 images so far...
# [antigone_rubicunda_300x300a] Created 300 images so far...
# [antigone_rubicunda_300x300a] Created 400 images so far...
# [antigone_rubicunda_300x300a] Created 500 images so far...
# Done 'antigone_rubicunda_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/antigone_rubicunda_300x300a'.
#
# Processing class 'aprosmictus_erythropterus_300x300a'
# Found 52 base images in '/content/drive/MyDrive/BIRDS_DATASET2/aprosmictus_erythropterus_300x300a'.
# Copied 52 original images to '/content/drive/MyDrive/Birds_Dataset3/aprosmictus_erythropterus_300x300a'.
# [aprosmictus_erythropterus_300x300a] Created 100 images so far...
# [aprosmictus_erythropterus_300x300a] Created 200 images so far...
# [aprosmictus_erythropterus_300x300a] Created 300 images so far...
# [aprosmictus_erythropterus_300x300a] Created 400 images so far...
# [aprosmictus_erythropterus_300x300a] Created 500 images so far...
# Done 'aprosmictus_erythropterus_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/aprosmictus_erythropterus_300x300a'.
#
# Processing class 'artamus_cinereus_300x300a'
# Found 34 base images in '/content/drive/MyDrive/BIRDS_DATASET2/artamus_cinereus_300x300a'.
# Copied 34 original images to '/content/drive/MyDrive/Birds_Dataset3/artamus_cinereus_300x300a'.
# [artamus_cinereus_300x300a] Created 100 images so far...
# [artamus_cinereus_300x300a] Created 200 images so far...
# [artamus_cinereus_300x300a] Created 300 images so far...
# [artamus_cinereus_300x300a] Created 400 images so far...
# [artamus_cinereus_300x300a] Created 500 images so far...
# Done 'artamus_cinereus_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/artamus_cinereus_300x300a'.
#
# Processing class 'artamus_cyanopterus_300x300a'
# Found 26 base images in '/content/drive/MyDrive/BIRDS_DATASET2/artamus_cyanopterus_300x300a'.
# Copied 26 original images to '/content/drive/MyDrive/Birds_Dataset3/artamus_cyanopterus_300x300a'.
# [artamus_cyanopterus_300x300a] Created 100 images so far...
# [artamus_cyanopterus_300x300a] Created 200 images so far...
# [artamus_cyanopterus_300x300a] Created 300 images so far...
# [artamus_cyanopterus_300x300a] Created 400 images so far...
# [artamus_cyanopterus_300x300a] Created 500 images so far...
# Done 'artamus_cyanopterus_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/artamus_cyanopterus_300x300a'.
#
# Processing class 'artamus_minor_300x300a'
# Found 6 base images in '/content/drive/MyDrive/BIRDS_DATASET2/artamus_minor_300x300a'.
# Copied 6 original images to '/content/drive/MyDrive/Birds_Dataset3/artamus_minor_300x300a'.
# [artamus_minor_300x300a] Created 100 images so far...
# [artamus_minor_300x300a] Created 200 images so far...
# [artamus_minor_300x300a] Created 300 images so far...
# [artamus_minor_300x300a] Created 400 images so far...
# [artamus_minor_300x300a] Created 500 images so far...
# Done 'artamus_minor_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/artamus_minor_300x300a'.
#
# Processing class 'artamus_superciliosus_300x300a'
# Found 24 base images in '/content/drive/MyDrive/BIRDS_DATASET2/artamus_superciliosus_300x300a'.
# Copied 24 original images to '/content/drive/MyDrive/Birds_Dataset3/artamus_superciliosus_300x300a'.
# [artamus_superciliosus_300x300a] Created 100 images so far...
# [artamus_superciliosus_300x300a] Created 200 images so far...
# [artamus_superciliosus_300x300a] Created 300 images so far...
# [artamus_superciliosus_300x300a] Created 400 images so far...
# [artamus_superciliosus_300x300a] Created 500 images so far...
# Done 'artamus_superciliosus_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/artamus_superciliosus_300x300a'.
#
# Processing class 'avesâ_sp._300x300a'
# Found 78 base images in '/content/drive/MyDrive/BIRDS_DATASET2/avesâ_sp._300x300a'.
# Copied 78 original images to '/content/drive/MyDrive/Birds_Dataset3/avesâ_sp._300x300a'.
# [avesâ_sp._300x300a] Created 100 images so far...
# [avesâ_sp._300x300a] Created 200 images so far...
# [avesâ_sp._300x300a] Created 300 images so far...
# [avesâ_sp._300x300a] Created 400 images so far...
# [avesâ_sp._300x300a] Created 500 images so far...
# Done 'avesâ_sp._300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/avesâ_sp._300x300a'.
#
# Processing class 'barnardius_zonarius_300x300a'
# Found 95 base images in '/content/drive/MyDrive/BIRDS_DATASET2/barnardius_zonarius_300x300a'.
# Copied 95 original images to '/content/drive/MyDrive/Birds_Dataset3/barnardius_zonarius_300x300a'.
# [barnardius_zonarius_300x300a] Created 100 images so far...
# [barnardius_zonarius_300x300a] Created 200 images so far...
# [barnardius_zonarius_300x300a] Created 300 images so far...
# [barnardius_zonarius_300x300a] Created 400 images so far...
# [barnardius_zonarius_300x300a] Created 500 images so far...
# Done 'barnardius_zonarius_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/barnardius_zonarius_300x300a'.
#
# Processing class 'biziura_lobata_300x300a'
# Found 38 base images in '/content/drive/MyDrive/BIRDS_DATASET2/biziura_lobata_300x300a'.
# Copied 38 original images to '/content/drive/MyDrive/Birds_Dataset3/biziura_lobata_300x300a'.
# [biziura_lobata_300x300a] Created 100 images so far...
# [biziura_lobata_300x300a] Created 200 images so far...
# [biziura_lobata_300x300a] Created 300 images so far...
# [biziura_lobata_300x300a] Created 400 images so far...
# [biziura_lobata_300x300a] Created 500 images so far...
# Done 'biziura_lobata_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/biziura_lobata_300x300a'.
#
# Processing class 'cacatua_sanguinea_300x300a'
# Found 80 base images in '/content/drive/MyDrive/BIRDS_DATASET2/cacatua_sanguinea_300x300a'.
# Copied 80 original images to '/content/drive/MyDrive/Birds_Dataset3/cacatua_sanguinea_300x300a'.
# [cacatua_sanguinea_300x300a] Created 100 images so far...
# [cacatua_sanguinea_300x300a] Created 200 images so far...
# [cacatua_sanguinea_300x300a] Created 300 images so far...
# [cacatua_sanguinea_300x300a] Created 400 images so far...
# [cacatua_sanguinea_300x300a] Created 500 images so far...
# Done 'cacatua_sanguinea_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/cacatua_sanguinea_300x300a'.
#
# Processing class 'cacomantis_flabelliformis_300x300a'
# Found 25 base images in '/content/drive/MyDrive/BIRDS_DATASET2/cacomantis_flabelliformis_300x300a'.
# Copied 25 original images to '/content/drive/MyDrive/Birds_Dataset3/cacomantis_flabelliformis_300x300a'.
# [cacomantis_flabelliformis_300x300a] Created 100 images so far...
# [cacomantis_flabelliformis_300x300a] Created 200 images so far...
# [cacomantis_flabelliformis_300x300a] Created 300 images so far...
# [cacomantis_flabelliformis_300x300a] Created 400 images so far...
# [cacomantis_flabelliformis_300x300a] Created 500 images so far...
# Done 'cacomantis_flabelliformis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/cacomantis_flabelliformis_300x300a'.
#
# Processing class 'caligavis_chrysops_300x300a'
# Found 36 base images in '/content/drive/MyDrive/BIRDS_DATASET2/caligavis_chrysops_300x300a'.
# Copied 36 original images to '/content/drive/MyDrive/Birds_Dataset3/caligavis_chrysops_300x300a'.
# [caligavis_chrysops_300x300a] Created 100 images so far...
# [caligavis_chrysops_300x300a] Created 200 images so far...
# [caligavis_chrysops_300x300a] Created 300 images so far...
# [caligavis_chrysops_300x300a] Created 400 images so far...
# [caligavis_chrysops_300x300a] Created 500 images so far...
# Done 'caligavis_chrysops_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/caligavis_chrysops_300x300a'.
#
# Processing class 'callocephalon_fimbriatum_300x300a'
# Found 50 base images in '/content/drive/MyDrive/BIRDS_DATASET2/callocephalon_fimbriatum_300x300a'.
# Copied 50 original images to '/content/drive/MyDrive/Birds_Dataset3/callocephalon_fimbriatum_300x300a'.
# [callocephalon_fimbriatum_300x300a] Created 100 images so far...
# [callocephalon_fimbriatum_300x300a] Created 200 images so far...
# [callocephalon_fimbriatum_300x300a] Created 300 images so far...
# [callocephalon_fimbriatum_300x300a] Created 400 images so far...
# [callocephalon_fimbriatum_300x300a] Created 500 images so far...
# Done 'callocephalon_fimbriatum_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/callocephalon_fimbriatum_300x300a'.
#
# Processing class 'calyptorhynchus_banksii_300x300a'
# Found 97 base images in '/content/drive/MyDrive/BIRDS_DATASET2/calyptorhynchus_banksii_300x300a'.
# Copied 97 original images to '/content/drive/MyDrive/Birds_Dataset3/calyptorhynchus_banksii_300x300a'.
# [calyptorhynchus_banksii_300x300a] Created 100 images so far...
# [calyptorhynchus_banksii_300x300a] Created 200 images so far...
# [calyptorhynchus_banksii_300x300a] Created 300 images so far...
# [calyptorhynchus_banksii_300x300a] Created 400 images so far...
# [calyptorhynchus_banksii_300x300a] Created 500 images so far...
# Done 'calyptorhynchus_banksii_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/calyptorhynchus_banksii_300x300a'.
#
# Processing class 'carduelis_carduelis_300x300a'
# Found 71 base images in '/content/drive/MyDrive/BIRDS_DATASET2/carduelis_carduelis_300x300a'.
# Copied 71 original images to '/content/drive/MyDrive/Birds_Dataset3/carduelis_carduelis_300x300a'.
# [carduelis_carduelis_300x300a] Created 100 images so far...
# [carduelis_carduelis_300x300a] Created 200 images so far...
# [carduelis_carduelis_300x300a] Created 300 images so far...
# [carduelis_carduelis_300x300a] Created 400 images so far...
# [carduelis_carduelis_300x300a] Created 500 images so far...
# Done 'carduelis_carduelis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/carduelis_carduelis_300x300a'.
#
# Processing class 'carterornis_leucotis_300x300a'
# Found 5 base images in '/content/drive/MyDrive/BIRDS_DATASET2/carterornis_leucotis_300x300a'.
# Copied 5 original images to '/content/drive/MyDrive/Birds_Dataset3/carterornis_leucotis_300x300a'.
# [carterornis_leucotis_300x300a] Created 100 images so far...
# [carterornis_leucotis_300x300a] Created 200 images so far...
# [carterornis_leucotis_300x300a] Created 300 images so far...
# [carterornis_leucotis_300x300a] Created 400 images so far...
# [carterornis_leucotis_300x300a] Created 500 images so far...
# Done 'carterornis_leucotis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/carterornis_leucotis_300x300a'.
#
# Processing class 'centropus_phasianinus_300x300a'
# Found 48 base images in '/content/drive/MyDrive/BIRDS_DATASET2/centropus_phasianinus_300x300a'.
# Copied 48 original images to '/content/drive/MyDrive/Birds_Dataset3/centropus_phasianinus_300x300a'.
# [centropus_phasianinus_300x300a] Created 100 images so far...
# [centropus_phasianinus_300x300a] Created 200 images so far...
# [centropus_phasianinus_300x300a] Created 300 images so far...
# [centropus_phasianinus_300x300a] Created 400 images so far...
# [centropus_phasianinus_300x300a] Created 500 images so far...
# Done 'centropus_phasianinus_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/centropus_phasianinus_300x300a'.
#
# Processing class 'ceyx_azureus_300x300a'
# Found 66 base images in '/content/drive/MyDrive/BIRDS_DATASET2/ceyx_azureus_300x300a'.
# Copied 66 original images to '/content/drive/MyDrive/Birds_Dataset3/ceyx_azureus_300x300a'.
# [ceyx_azureus_300x300a] Created 100 images so far...
# [ceyx_azureus_300x300a] Created 200 images so far...
# [ceyx_azureus_300x300a] Created 300 images so far...
# [ceyx_azureus_300x300a] Created 400 images so far...
# [ceyx_azureus_300x300a] Created 500 images so far...
# Done 'ceyx_azureus_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/ceyx_azureus_300x300a'.
#
# Processing class 'coracina_novaehollandiae_300x300a'
# Found 90 base images in '/content/drive/MyDrive/BIRDS_DATASET2/coracina_novaehollandiae_300x300a'.
# Copied 90 original images to '/content/drive/MyDrive/Birds_Dataset3/coracina_novaehollandiae_300x300a'.
# [coracina_novaehollandiae_300x300a] Created 100 images so far...
# [coracina_novaehollandiae_300x300a] Created 200 images so far...
# [coracina_novaehollandiae_300x300a] Created 300 images so far...
# [coracina_novaehollandiae_300x300a] Created 400 images so far...
# [coracina_novaehollandiae_300x300a] Created 500 images so far...
# Done 'coracina_novaehollandiae_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/coracina_novaehollandiae_300x300a'.
#
# Processing class 'coracina_papuensis_300x300a'
# Found 11 base images in '/content/drive/MyDrive/BIRDS_DATASET2/coracina_papuensis_300x300a'.
# Copied 11 original images to '/content/drive/MyDrive/Birds_Dataset3/coracina_papuensis_300x300a'.
# [coracina_papuensis_300x300a] Created 100 images so far...
# [coracina_papuensis_300x300a] Created 200 images so far...
# [coracina_papuensis_300x300a] Created 300 images so far...
# [coracina_papuensis_300x300a] Created 400 images so far...
# [coracina_papuensis_300x300a] Created 500 images so far...
# Done 'coracina_papuensis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/coracina_papuensis_300x300a'.
#
# Processing class 'corcorax_melanorhamphos_300x300a'
# Found 41 base images in '/content/drive/MyDrive/BIRDS_DATASET2/corcorax_melanorhamphos_300x300a'.
# Copied 41 original images to '/content/drive/MyDrive/Birds_Dataset3/corcorax_melanorhamphos_300x300a'.
# [corcorax_melanorhamphos_300x300a] Created 100 images so far...
# [corcorax_melanorhamphos_300x300a] Created 200 images so far...
# [corcorax_melanorhamphos_300x300a] Created 300 images so far...
# [corcorax_melanorhamphos_300x300a] Created 400 images so far...
# [corcorax_melanorhamphos_300x300a] Created 500 images so far...
# Done 'corcorax_melanorhamphos_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/corcorax_melanorhamphos_300x300a'.
#
# Processing class 'cormobates_leucophaea_300x300a'
# Found 31 base images in '/content/drive/MyDrive/BIRDS_DATASET2/cormobates_leucophaea_300x300a'.
# Copied 31 original images to '/content/drive/MyDrive/Birds_Dataset3/cormobates_leucophaea_300x300a'.
# [cormobates_leucophaea_300x300a] Created 100 images so far...
# [cormobates_leucophaea_300x300a] Created 200 images so far...
# [cormobates_leucophaea_300x300a] Created 300 images so far...
# [cormobates_leucophaea_300x300a] Created 400 images so far...
# [cormobates_leucophaea_300x300a] Created 500 images so far...
# Done 'cormobates_leucophaea_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/cormobates_leucophaea_300x300a'.
#
# Processing class 'corvus_orru_300x300a'
# Found 70 base images in '/content/drive/MyDrive/BIRDS_DATASET2/corvus_orru_300x300a'.
# Copied 70 original images to '/content/drive/MyDrive/Birds_Dataset3/corvus_orru_300x300a'.
# [corvus_orru_300x300a] Created 100 images so far...
# [corvus_orru_300x300a] Created 200 images so far...
# [corvus_orru_300x300a] Created 300 images so far...
# [corvus_orru_300x300a] Created 400 images so far...
# [corvus_orru_300x300a] Created 500 images so far...
# Done 'corvus_orru_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/corvus_orru_300x300a'.
#
# Processing class 'coturnix_pectoralis_300x300a'
# Found 6 base images in '/content/drive/MyDrive/BIRDS_DATASET2/coturnix_pectoralis_300x300a'.
# Copied 6 original images to '/content/drive/MyDrive/Birds_Dataset3/coturnix_pectoralis_300x300a'.
# [coturnix_pectoralis_300x300a] Created 100 images so far...
# [coturnix_pectoralis_300x300a] Created 200 images so far...
# [coturnix_pectoralis_300x300a] Created 300 images so far...
# [coturnix_pectoralis_300x300a] Created 400 images so far...
# [coturnix_pectoralis_300x300a] Created 500 images so far...
# Done 'coturnix_pectoralis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/coturnix_pectoralis_300x300a'.
#
# Processing class 'cracticus_nigrogularis_300x300a'
# Found 70 base images in '/content/drive/MyDrive/BIRDS_DATASET2/cracticus_nigrogularis_300x300a'.
# Copied 70 original images to '/content/drive/MyDrive/Birds_Dataset3/cracticus_nigrogularis_300x300a'.
# [cracticus_nigrogularis_300x300a] Created 100 images so far...
# [cracticus_nigrogularis_300x300a] Created 200 images so far...
# [cracticus_nigrogularis_300x300a] Created 300 images so far...
# [cracticus_nigrogularis_300x300a] Created 400 images so far...
# [cracticus_nigrogularis_300x300a] Created 500 images so far...
# Done 'cracticus_nigrogularis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/cracticus_nigrogularis_300x300a'.
#
# Processing class 'cracticus_torquatus_300x300a'
# Found 63 base images in '/content/drive/MyDrive/BIRDS_DATASET2/cracticus_torquatus_300x300a'.
# Copied 63 original images to '/content/drive/MyDrive/Birds_Dataset3/cracticus_torquatus_300x300a'.
# [cracticus_torquatus_300x300a] Created 100 images so far...
# [cracticus_torquatus_300x300a] Created 200 images so far...
# [cracticus_torquatus_300x300a] Created 300 images so far...
# [cracticus_torquatus_300x300a] Created 400 images so far...
# [cracticus_torquatus_300x300a] Created 500 images so far...
# Done 'cracticus_torquatus_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/cracticus_torquatus_300x300a'.
#
# Processing class 'zosterops_lateralis_300x300a'
# Found 27 base images in '/content/drive/MyDrive/BIRDS_DATASET2/zosterops_lateralis_300x300a'.
# Copied 27 original images to '/content/drive/MyDrive/Birds_Dataset3/zosterops_lateralis_300x300a'.
# [zosterops_lateralis_300x300a] Created 100 images so far...
# [zosterops_lateralis_300x300a] Created 200 images so far...
# [zosterops_lateralis_300x300a] Created 300 images so far...
# [zosterops_lateralis_300x300a] Created 400 images so far...
# [zosterops_lateralis_300x300a] Created 500 images so far...
# Done 'zosterops_lateralis_300x300a'. Saved 500 images total in '/content/drive/MyDrive/Birds_Dataset3/zosterops_lateralis_300x300a'.
#
# All class folders processed.
