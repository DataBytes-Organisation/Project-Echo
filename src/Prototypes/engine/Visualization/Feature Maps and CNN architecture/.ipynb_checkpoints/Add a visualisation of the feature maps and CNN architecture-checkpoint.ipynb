# %%
# !conda install -c conda-forge opencv -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\ANACONDA\envs\newgpu_clone
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       h56e8100_0         146 KB  conda-forge
#     certifi-2023.7.22          |     pyhd8ed1ab_0         150 KB  conda-forge
#     eigen-3.4.0                |       h2d74725_0         1.2 MB  conda-forge
#     ffmpeg-4.2.3               |       ha925a31_0        23.2 MB  conda-forge
#     jupyter_server-1.23.4      |   py39haa95532_0         399 KB
#     opencv-4.6.0               |   py39ha36de5b_5        29.9 MB
#     ------------------------------------------------------------
#                                            Total:        54.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   eigen              conda-forge/win-64::eigen-3.4.0-h2d74725_0
#   ffmpeg             conda-forge/win-64::ffmpeg-4.2.3-ha925a31_0
#   opencv             pkgs/main/win-64::opencv-4.6.0-py39ha36de5b_5
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1v-h2bbff1b_0 --> 1.1.1w-h2bbff1b_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.08.22~ --> conda-forge::ca-certificates-2023.7.22-h56e8100_0
#   certifi            pkgs/main/win-64::certifi-2023.7.22-p~ --> conda-forge/noarch::certifi-2023.7.22-pyhd8ed1ab_0
#
# The following packages will be DOWNGRADED:
#
#   jupyter_server                       2.5.0-py39haa95532_0 --> 1.23.4-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2023 | 146 KB    |            |   0%
#
# eigen-3.4.0          | 1.2 MB    |            |   0%
#
#
# ffmpeg-4.2.3         | 23.2 MB   |            |   0%
#
#
#
# jupyter_server-1.23. | 399 KB    |            |   0%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   |            |   0%
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    |            |   0%
#
#
#
# jupyter_server-1.23. | 399 KB    | #######6   |  76%
#
#
# ffmpeg-4.2.3         | 23.2 MB   |            |   0%
# ca-certificates-2023 | 146 KB    | #          |  11%
#
# eigen-3.4.0          | 1.2 MB    | 1          |   1%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | 2          |   3%
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    | #          |  11%
# ca-certificates-2023 | 146 KB    | ########## | 100%
# ca-certificates-2023 | 146 KB    | ########## | 100%
#
# eigen-3.4.0          | 1.2 MB    | 6          |   7%
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    | ########## | 100%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | 4          |   4%
#
# eigen-3.4.0          | 1.2 MB    | ##6        |  26%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   |            |   0%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | 6          |   6%
#
# eigen-3.4.0          | 1.2 MB    | ####6      |  47%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   |            |   1%
#
#
#
# jupyter_server-1.23. | 399 KB    | ########## | 100%
#
# eigen-3.4.0          | 1.2 MB    | ######7    |  68%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | 1          |   1%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | 7          |   7%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | 2          |   3%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | 8          |   9%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | 4          |   4%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | 9          |  10%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | 5          |   5%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #1         |  11%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | 6          |   7%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #2         |  13%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | 7          |   8%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #4         |  14%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | 8          |   9%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #5         |  16%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | 9          |  10%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #7         |  17%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #          |  11%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #9         |  19%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #2         |  12%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ##         |  21%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #3         |  13%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ##2        |  22%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #4         |  14%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ##3        |  24%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #5         |  15%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ##5        |  25%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #6         |  16%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ##6        |  27%
#
# eigen-3.4.0          | 1.2 MB    | ########## | 100%
#
# eigen-3.4.0          | 1.2 MB    | ########## | 100%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #7         |  17%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ##8        |  28%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #8         |  19%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ##9        |  30%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #9         |  20%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ###1       |  31%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ##         |  21%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ###2       |  33%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ##2        |  22%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ###4       |  34%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ##3        |  23%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ###5       |  36%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ##4        |  24%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ###7       |  37%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ##5        |  26%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ###8       |  39%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ##6        |  27%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ####       |  40%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ##7        |  28%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ####1      |  41%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ##9        |  29%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ####2      |  43%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###        |  30%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ####4      |  44%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###1       |  31%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ####5      |  46%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###2       |  33%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ####7      |  47%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###3       |  34%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ####8      |  49%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###4       |  35%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ####9      |  50%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###6       |  36%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #####1     |  51%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###7       |  37%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #####2     |  53%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###8       |  39%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #####4     |  54%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ###9       |  40%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #####5     |  56%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ####       |  41%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #####7     |  57%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ####1      |  42%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #####8     |  59%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ####3      |  43%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #####9     |  60%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ####4      |  44%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ######1    |  61%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ####5      |  45%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ######2    |  63%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ####6      |  47%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ######4    |  64%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ####7      |  48%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ######5    |  66%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ####9      |  49%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ######7    |  67%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####      |  50%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ######8    |  68%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####1     |  51%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ######9    |  70%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####2     |  52%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #######1   |  71%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####3     |  54%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #######2   |  73%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####4     |  55%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #######4   |  74%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####5     |  56%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #######5   |  76%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####7     |  57%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #######6   |  77%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####8     |  58%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #######8   |  78%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #####9     |  59%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #######9   |  80%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ######     |  61%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ########1  |  81%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ######1    |  62%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ########2  |  83%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ######2    |  63%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ######4    |  64%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ########4  |  84%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ######5    |  66%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ########5  |  85%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ######6    |  67%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ########6  |  87%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ######8    |  68%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ########8  |  88%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ######9    |  69%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ########9  |  90%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #######    |  71%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #########  |  91%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #######1   |  72%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #########2 |  92%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #######2   |  73%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #########3 |  94%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #######4   |  74%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #########5 |  95%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #########6 |  96%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #######5   |  75%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #########7 |  98%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #######6   |  77%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | #########9 |  99%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #######7   |  78%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #######9   |  79%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ########1  |  82%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ########3  |  84%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ########6  |  86%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ########8  |  88%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #########  |  91%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #########2 |  93%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #########5 |  95%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #########7 |  97%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | #########9 |  99%
#
#
# ffmpeg-4.2.3         | 23.2 MB   | ########## | 100%
#
#
#
#
# opencv-4.6.0         | 29.9 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==custom=py39_2
#   - defaults/win-64::jupyter==1.0.0=py39haa95532_8
#   - defaults/win-64::jupyterlab==3.6.3=py39haa95532_0
#   - defaults/win-64::jupyterlab_server==2.22.0=py39haa95532_0
#   - defaults/win-64::jupyter_server==2.5.0=py39haa95532_0
#   - defaults/win-64::jupyter_server_fileid==0.9.0=py39haa95532_0
#   - defaults/win-64::jupyter_server_ydoc==0.8.0=py39haa95532_1
#   - defaults/win-64::nbclassic==0.5.5=py39haa95532_0
#   - defaults/win-64::notebook==6.5.4=py39haa95532_0
#   - defaults/win-64::notebook-shim==0.2.2=py39haa95532_0
#   - defaults/win-64::_anaconda_depends==2023.07=py39_0
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39haa95532_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.3
#   latest version: 23.7.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.4

# %%
import numpy as np
import os
import glob
import librosa
from tensorflow.keras import models
from tensorflow.keras.applications import VGG16
import librosa.display
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
# Out:
# D:\ANACONDA\envs\newgpu_clone\lib\site-packages\lazy_loader\__init__.py:185: RuntimeWarning: subpackages can technically be lazily loaded, but it causes the package to be eagerly loaded even if it is already lazily loaded.So, you probably shouldn't use subpackages with this lazy feature.
#   warnings.warn(msg, RuntimeWarning)
# D:\ANACONDA\envs\newgpu_clone\lib\site-packages\lazy_loader\__init__.py:185: RuntimeWarning: subpackages can technically be lazily loaded, but it causes the package to be eagerly loaded even if it is already lazily loaded.So, you probably shouldn't use subpackages with this lazy feature.
#   warnings.warn(msg, RuntimeWarning)

# %%
def load_audio_data(file_path):
    data = []
    labels = []
    sample_rates = []
    for subfolder in os.listdir(file_path):
        subfolder_path = os.path.join(file_path, subfolder)
        if os.path.isdir(subfolder_path):
            for file in glob.glob(os.path.join(subfolder_path, '*.wav')):
                # Load audio files
                y, sr = librosa.load(file, sr=None)
                data.append(y)
                sample_rates.append(sr)
                labels.append(subfolder)  # Store folder name (animal name) as label
    return data, labels, sample_rates

# Call function to load data
data_path = "D:\\data\\AnimalSound\\ebird1"
audio_data, audio_labels, sample_rates = load_audio_data(data_path)

# %%
# Normalize the data.
def preprocess_data(data):
    preprocessed_data = []
    for y in data:
        normalized_data = librosa.util.normalize(y)
        preprocessed_data.append(normalized_data)
    
    return preprocessed_data

# Call function for preprocessing
preprocessed_data = preprocess_data(audio_data)

# %%
#from tensorflow.keras.models import load_mode

# Load your model
# model = load_model('C:\\Users\\93978\\Documents\\GitHub\\Project-Echo\\Transfer learning\\SWe_OpenL3\\models\\echo_model\\1')
base_model = VGG16(weights='imagenet', include_top=False)

# %%
# List the names and indices of all layers
#for i, layer in enumerate(model.layers):
    #print(i, layer.name)
for i, layer in enumerate(base_model.layers):
    print(i, layer.name)
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_pool
# 11 block4_conv1
# 12 block4_conv2
# 13 block4_conv3
# 14 block4_pool
# 15 block5_conv1
# 16 block5_conv2
# 17 block5_conv3
# 18 block5_pool

# %%
# Take the first audio sample to create a spectrogram
sample = audio_data[0]
sr = sample_rates[0]  

# Generate mel spectrogram
mel_spectrogram = librosa.feature.melspectrogram(y=sample, sr=sr, n_mels=128)

# Convert to log mel spectrogram
log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

# Convert spectrogram to RGB image
plt.figure()
librosa.display.specshow(log_mel_spectrogram, sr=sr, x_axis='time', y_axis='mel')

# save image
plt.savefig('spectrogram.png')
plt.close()

# Reading images using cv2
pixels = cv2.imread('spectrogram.png')

# Resize the image to match the input dimensions of VGG16
pixels = cv2.resize(pixels, (224, 224))

# %%
# Extract the output of a specific layer
layer_outputs = [base_model.get_layer('block1_conv1').output]  # Please replace with the name of the layer of your choice

# Create a model that outputs the output of these layers given an input image
activation_model = models.Model(inputs=base_model.input, outputs=layer_outputs)

# Choose an input sample and prepare it 
input_sample = np.expand_dims(pixels, axis=0)  # Replace with your preprocessed data, reshaped to the appropriate input size for VGG16 (224, 224, 3)

# Get feature map
feature_maps = activation_model.predict(input_sample)

# Visual feature mapping
n_features = feature_maps.shape[-1]  # Get the number of feature maps

# This will be the size of the subplot
size = int(np.ceil(np.sqrt(n_features)))

plt.figure(figsize=(10, 10))
for i in range(n_features):
    plt.subplot(size, size, i+1)
    plt.imshow(feature_maps[0, :, :, i], cmap='viridis')  # Adjust the indices to match the dimensions of the feature maps
    plt.axis('off')

# Adjust layout to avoid overlap between subplots
plt.tight_layout()

plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 28
#      25 # Adjust layout to avoid overlap between subplots
#      26 plt.tight_layout()
# ---> 28 plt.show()
#
# File D:\ANACONDA\envs\newgpu_clone\lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File D:\ANACONDA\envs\newgpu_clone\lib\site-packages\matplotlib_inline\backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File D:\ANACONDA\envs\newgpu_clone\lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\ANACONDA\envs\newgpu_clone\lib\site-packages\matplotlib_inline\backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File D:\ANACONDA\envs\newgpu_clone\lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %%
# !pip install pydot graphviz
# Out:
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 0.0/47.0 kB ? eta -:--:--
#      ---------------------------------------- 47.0/47.0 kB ? eta 0:00:00
# Requirement already satisfied: pyparsing>=2.1.4 in d:\anaconda\envs\newgpu_clone\lib\site-packages (from pydot) (3.0.9)
# Installing collected packages: pydot, graphviz
# Successfully installed graphviz-0.20.1 pydot-1.4.2

# %%
# Please install the Graphviz binaries(https://graphviz.gitlab.io/download/)

# %%
# Visualize the base_model
plot_model(base_model, to_file='base_model.png', show_shapes=True, show_layer_names=True)

# %%
# !pip install visualkeras
# !pip install pillow
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\envs\newgpu_clone\lib\site-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in d:\anaconda\envs\newgpu_clone\lib\site-packages (from visualkeras) (1.24.3)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp39-cp39-win_amd64.whl (43 kB)
#      ---------------------------------------- 0.0/43.2 kB ? eta -:--:--
#      ---------------------------------------- 43.2/43.2 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2
# Requirement already satisfied: pillow in d:\anaconda\envs\newgpu_clone\lib\site-packages (9.4.0)

# %%
import visualkeras
from PIL import ImageFont
from tensorflow.keras import Input

base_model = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# Use visualkeras to visualize the model
visualkeras.layered_view(base_model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1007x1231>
