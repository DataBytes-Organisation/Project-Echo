# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
audio_path = '/Users/atulrane/Documents/Project Echo/Project-Echo/src/Prototypes/engine/Cam_to_mel_ar/dog-bark1.wav'
output_mel_path = '/Users/atulrane/Documents/Project Echo/Project-Echo/src/Prototypes/engine/Cam_to_mel_ar/mel_spectrogram.png'

# %%
def create_mel_spectrogram(audio_path, output_path):
    y, sr = librosa.load(audio_path)
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
    mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)

# Save the Mel spectrogram as an image
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mel_spectrogram_db, sr=sr, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel Spectrogram')
    plt.tight_layout()
    plt.savefig(output_path)
    plt.close()
    
    return mel_spectrogram_db, sr

# %%
# Generate and save Mel spectrogram
mel_spectrogram, sr = create_mel_spectrogram(audio_path, output_mel_path)

# %%
plt.figure(figsize=(10, 4))
librosa.display.specshow(mel_spectrogram, sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram')
plt.tight_layout()
plt.show()
