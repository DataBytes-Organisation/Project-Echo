# %%
import pyaudio
import librosa
import numpy as np
import matplotlib.pyplot as plt
import keras

import yamnet.params as params
import yamnet.yamnet as yamnet_model
yamnet = yamnet_model.yamnet_frames_model(params)
yamnet.load_weights('yamnet/yamnet.h5')
yamnet_classes = yamnet_model.class_names('yamnet/yamnet_class_map.csv')

frame_len = int(params.SAMPLE_RATE * 1) # 1sec

p = pyaudio.PyAudio()
stream = p.open(format=pyaudio.paInt16,
                channels=1,
                rate=params.SAMPLE_RATE,
                input=True,
                frames_per_buffer=frame_len)

cnt = 0
plt.ion()
while True:
    # data read
    data = stream.read(frame_len, exception_on_overflow=False)

    # byte --> float
    frame_data = librosa.util.buf_to_float(data, n_bytes=2, dtype=np.int16)

    # model prediction
    scores, melspec = yamnet.predict(np.reshape(frame_data, [1, -1]), steps=1)
    prediction = np.mean(scores, axis=0)

    # visualize input audio
    plt.imshow(melspec.T, cmap='jet', aspect='auto', origin='lower')
    plt.pause(0.001)
    plt.show()

    top5_i = np.argsort(prediction)[::-1][:5]

    # print result
    print('Current event:\n' +
          '\n'.join('  {:12s}: {:.3f}'.format(yamnet_classes[i], prediction[i])
                    for i in top5_i))

    # print idx
    print(cnt)
    cnt += 1

stream.stop_stream()
stream.close()
p.terminate()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 0
# 1/1 [==============================] - 0s 24ms/step
# Current event:
#   Silence     : 0.994
#   Speech      : 0.000
#   Outside, rural or natural: 0.000
#   Outside, urban or manmade: 0.000
#   Vehicle     : 0.000
# 1
# 1/1 [==============================] - 0s 19ms/step
# Current event:
#   Silence     : 0.203
#   Vehicle     : 0.094
#   Motor vehicle (road): 0.079
#   Outside, urban or manmade: 0.074
#   Car         : 0.066
# 2
# 1/1 [==============================] - 0s 37ms/step
# Current event:
#   Silence     : 0.708
#   Sound effect: 0.025
#   Outside, rural or natural: 0.019
#   Explosion   : 0.014
#   Outside, urban or manmade: 0.014
# 3
# 1/1 [==============================] - 0s 21ms/step
# Current event:
#   Silence     : 0.961
#   Sound effect: 0.002
#   Outside, rural or natural: 0.001
#   Inside, small room: 0.001
#   Outside, urban or manmade: 0.000
# 4
# 1/1 [==============================] - 0s 20ms/step
# Current event:
#   Silence     : 0.628
#   Inside, small room: 0.004
#   Outside, rural or natural: 0.003
#   Speech      : 0.003
#   Explosion   : 0.002
# 5
# 1/1 [==============================] - 0s 21ms/step
# Current event:
#   Silence     : 0.988
#   Speech      : 0.001
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 6
# 1/1 [==============================] - 0s 30ms/step
# Current event:
#   Silence     : 0.988
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 7
# 1/1 [==============================] - 0s 147ms/step
# Current event:
#   Silence     : 0.652
#   Inside, small room: 0.019
#   Clicking    : 0.018
#   Speech      : 0.013
#   Tick        : 0.009
# 8
# 1/1 [==============================] - 0s 41ms/step
# Current event:
#   Silence     : 0.259
#   Sound effect: 0.034
#   Vehicle     : 0.033
#   Outside, rural or natural: 0.026
#   Outside, urban or manmade: 0.023
# 9
# 1/1 [==============================] - 0s 60ms/step
# Current event:
#   Silence     : 0.812
#   Sound effect: 0.014
#   Outside, rural or natural: 0.007
#   Outside, urban or manmade: 0.006
#   Vehicle     : 0.005
# 10
# 1/1 [==============================] - 0s 68ms/step
# Current event:
#   Silence     : 0.622
#   Inside, small room: 0.015
#   Speech      : 0.013
#   Clicking    : 0.008
#   Outside, rural or natural: 0.003
# 11
# 1/1 [==============================] - 0s 53ms/step
# Current event:
#   Silence     : 0.532
#   Inside, small room: 0.029
#   Outside, rural or natural: 0.018
#   Arrow       : 0.018
#   Fire        : 0.012
# 12
# 1/1 [==============================] - 0s 59ms/step
# Current event:
#   Silence     : 0.799
#   Speech      : 0.010
#   Inside, small room: 0.006
#   Clicking    : 0.004
#   Sound effect: 0.002
# 13
# 1/1 [==============================] - 0s 27ms/step
# Current event:
#   Silence     : 0.696
#   Animal      : 0.020
#   Wild animals: 0.018
#   Bird        : 0.013
#   Inside, small room: 0.012
# 14
# 1/1 [==============================] - 0s 25ms/step
# Current event:
#   Domestic animals, pets: 0.928
#   Animal      : 0.928
#   Cat         : 0.898
#   Meow        : 0.638
#   Inside, small room: 0.024
# 15
# 1/1 [==============================] - 0s 24ms/step
# Current event:
#   Speech      : 0.358
#   Child speech, kid speaking: 0.284
#   Babbling    : 0.155
#   Inside, small room: 0.095
#   Child singing: 0.059
# 16
# 1/1 [==============================] - 0s 46ms/step
# Current event:
#   Silence     : 0.860
#   Inside, small room: 0.005
#   Speech      : 0.004
#   Inside, large room or hall: 0.001
#   Writing     : 0.001
# 17
# 1/1 [==============================] - 0s 22ms/step
# Current event:
#   Silence     : 0.994
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 18
# 1/1 [==============================] - 0s 20ms/step
# Current event:
#   Silence     : 0.969
#   Speech      : 0.002
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 19
# 1/1 [==============================] - 0s 352ms/step
# Current event:
#   Silence     : 0.501
#   Fire        : 0.046
#   Camera      : 0.043
#   Crackle     : 0.039
#   Outside, rural or natural: 0.025
# 20
# 1/1 [==============================] - 0s 154ms/step
# Current event:
#   Chime       : 0.384
#   Glass       : 0.310
#   Bell        : 0.307
#   Chink, clink: 0.291
#   Wind chime  : 0.270
# 21
# 1/1 [==============================] - 0s 35ms/step
# Current event:
#   Silence     : 0.591
#   Inside, small room: 0.067
#   Clicking    : 0.021
#   Speech      : 0.017
#   Child speech, kid speaking: 0.006
# 22
# 1/1 [==============================] - 0s 134ms/step
# Current event:
#   Speech      : 0.865
#   Child speech, kid speaking: 0.044
#   Cat         : 0.014
#   Inside, small room: 0.014
#   Domestic animals, pets: 0.013
# 23
# 1/1 [==============================] - 0s 138ms/step
# Current event:
#   Cat         : 0.894
#   Domestic animals, pets: 0.767
#   Meow        : 0.755
#   Animal      : 0.581
#   Caterwaul   : 0.278
# 24
# 1/1 [==============================] - 0s 44ms/step
# Current event:
#   Silence     : 0.949
#   Inside, small room: 0.004
#   Speech      : 0.003
#   Inside, large room or hall: 0.000
#   Narration, monologue: 0.000
# 25
# 1/1 [==============================] - 0s 33ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 26
# 1/1 [==============================] - 0s 26ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 27
# 1/1 [==============================] - 0s 20ms/step
# Current event:
#   Silence     : 0.985
#   Speech      : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
#   Inside, large room or hall: 0.000
# 28
# 1/1 [==============================] - 0s 46ms/step
# Current event:
#   Silence     : 0.651
#   Inside, small room: 0.026
#   Writing     : 0.019
#   Spray       : 0.015
#   Speech      : 0.010
# 29
# 1/1 [==============================] - 0s 19ms/step
# Current event:
#   Silence     : 0.148
#   Inside, small room: 0.067
#   Speech      : 0.055
#   Domestic animals, pets: 0.011
#   Inside, large room or hall: 0.010
# 30
# 1/1 [==============================] - 0s 23ms/step
# Current event:
#   Silence     : 0.854
#   Speech      : 0.006
#   Animal      : 0.001
#   Inside, small room: 0.001
#   Outside, rural or natural: 0.001
# 31
# 1/1 [==============================] - 0s 19ms/step
# Current event:
#   Silence     : 0.590
#   Speech      : 0.013
#   Inside, small room: 0.004
#   Sound effect: 0.002
#   Clicking    : 0.002
# 32
# 1/1 [==============================] - 0s 88ms/step
# Current event:
#   Silence     : 0.841
#   Speech      : 0.008
#   Inside, small room: 0.003
#   Animal      : 0.003
#   Outside, rural or natural: 0.002
# 33
# 1/1 [==============================] - 0s 24ms/step
# Current event:
#   Cat         : 0.982
#   Animal      : 0.949
#   Domestic animals, pets: 0.944
#   Meow        : 0.896
#   Caterwaul   : 0.375
# 34
# 1/1 [==============================] - 0s 88ms/step
# Current event:
#   Silence     : 0.537
#   Inside, small room: 0.013
#   Animal      : 0.011
#   Wild animals: 0.010
#   Speech      : 0.010
# 35
# 1/1 [==============================] - 0s 145ms/step
# Current event:
#   Silence     : 0.999
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 36
# 1/1 [==============================] - 0s 105ms/step
# Current event:
#   Silence     : 0.935
#   Sound effect: 0.005
#   Outside, rural or natural: 0.005
#   Outside, urban or manmade: 0.003
#   Bird        : 0.002
# 37
# 1/1 [==============================] - 0s 84ms/step
# Current event:
#   Silence     : 0.535
#   Animal      : 0.034
#   Sound effect: 0.033
#   Outside, rural or natural: 0.033
#   Wild animals: 0.029
# 38
# 1/1 [==============================] - 0s 27ms/step
# Current event:
#   Silence     : 0.463
#   Breathing   : 0.046
#   Snort       : 0.040
#   Animal      : 0.040
#   Inside, small room: 0.038
# 39
# 1/1 [==============================] - 0s 21ms/step
# Current event:
#   Dog         : 0.482
#   Domestic animals, pets: 0.458
#   Animal      : 0.255
#   Bark        : 0.250
#   Bow-wow     : 0.235
# 40
# 1/1 [==============================] - 0s 20ms/step
# Current event:
#   Domestic animals, pets: 0.478
#   Dog         : 0.466
#   Animal      : 0.371
#   Bow-wow     : 0.329
#   Canidae, dogs, wolves: 0.224
# 41
# 1/1 [==============================] - 0s 61ms/step
# Current event:
#   Dog         : 0.309
#   Domestic animals, pets: 0.285
#   Animal      : 0.189
#   Bark        : 0.134
#   Babbling    : 0.114
# 42
# 1/1 [==============================] - 0s 21ms/step
# Current event:
#   Gargling    : 0.287
#   Dog         : 0.282
#   Domestic animals, pets: 0.277
#   Animal      : 0.246
#   Humming     : 0.232
# 43
# 1/1 [==============================] - 0s 22ms/step
# Current event:
#   Dog         : 0.638
#   Domestic animals, pets: 0.599
#   Bow-wow     : 0.476
#   Bark        : 0.424
#   Animal      : 0.362
# 44
# 1/1 [==============================] - 0s 35ms/step
# Current event:
#   Silence     : 0.917
#   Speech      : 0.005
#   Inside, small room: 0.002
#   Clicking    : 0.001
#   Outside, rural or natural: 0.001
# 45
# 1/1 [==============================] - 0s 31ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 46
# 1/1 [==============================] - 0s 139ms/step
# Current event:
#   Silence     : 0.998
#   Speech      : 0.002
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 47
# 1/1 [==============================] - 0s 88ms/step
# Current event:
#   Speech      : 0.589
#   Domestic animals, pets: 0.185
#   Dog         : 0.125
#   Animal      : 0.103
#   Bow-wow     : 0.012
# 48
# 1/1 [==============================] - 0s 43ms/step
# Current event:
#   Gargling    : 0.356
#   Dog         : 0.350
#   Domestic animals, pets: 0.318
#   Animal      : 0.207
#   Bark        : 0.175
# 49
# 1/1 [==============================] - 0s 57ms/step
# Current event:
#   Gargling    : 0.386
#   Dog         : 0.163
#   Domestic animals, pets: 0.097
#   Beatboxing  : 0.086
#   Laughter    : 0.080
# 50
# 1/1 [==============================] - 0s 28ms/step
# Current event:
#   Speech      : 0.607
#   Inside, small room: 0.022
#   Conversation: 0.015
#   Child speech, kid speaking: 0.010
#   Laughter    : 0.008
# 51
# 1/1 [==============================] - 0s 23ms/step
# Current event:
#   Dog         : 0.260
#   Domestic animals, pets: 0.231
#   Animal      : 0.204
#   Bark        : 0.191
#   Gargling    : 0.102
# 52
# 1/1 [==============================] - 0s 20ms/step
# Current event:
#   Silence     : 0.514
#   Inside, small room: 0.072
#   Speech      : 0.043
#   Arrow       : 0.028
#   Whoosh, swoosh, swish: 0.023
# 53
# 1/1 [==============================] - 0s 19ms/step
# Current event:
#   Speech      : 0.792
#   Inside, small room: 0.014
#   Breathing   : 0.014
#   Gasp        : 0.012
#   Dog         : 0.006
# 54
# 1/1 [==============================] - 0s 34ms/step
# Current event:
#   Animal      : 0.162
#   Speech      : 0.154
#   Dog         : 0.129
#   Domestic animals, pets: 0.094
#   Livestock, farm animals, working animals: 0.092
# 55
# 1/1 [==============================] - 0s 20ms/step
# Current event:
#   Speech      : 0.172
#   Inside, small room: 0.058
#   Singing     : 0.019
#   Conversation: 0.017
#   Laughter    : 0.017
# 56
# 1/1 [==============================] - 0s 61ms/step
# Current event:
#   Humming     : 0.728
#   Vocal music : 0.155
#   A capella   : 0.139
#   Singing     : 0.093
#   Beatboxing  : 0.076
# 57
# 1/1 [==============================] - 0s 150ms/step
# Current event:
#   Speech      : 0.254
#   Babbling    : 0.120
#   Humming     : 0.100
#   Inside, small room: 0.078
#   Child speech, kid speaking: 0.060
# 58
# 1/1 [==============================] - 0s 225ms/step
# Current event:
#   Silence     : 0.784
#   Inside, small room: 0.007
#   Clicking    : 0.003
#   Outside, rural or natural: 0.003
#   Mechanisms  : 0.003
# 59
# 1/1 [==============================] - 0s 120ms/step
# Current event:
#   Typing      : 0.827
#   Computer keyboard: 0.688
#   Silence     : 0.032
#   Inside, small room: 0.020
#   Clicking    : 0.010
# 60
# 1/1 [==============================] - 0s 326ms/step
# Current event:
#   Silence     : 0.973
#   Speech      : 0.002
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 61
# 1/1 [==============================] - 0s 65ms/step
# Current event:
#   Silence     : 0.949
#   Speech      : 0.001
#   Inside, small room: 0.000
#   Narration, monologue: 0.000
#   Music       : 0.000
# 62
# 1/1 [==============================] - 0s 38ms/step
# Current event:
#   Silence     : 0.499
#   Inside, small room: 0.084
#   Animal      : 0.012
#   Domestic animals, pets: 0.010
#   Clicking    : 0.010
# 63
# 1/1 [==============================] - 0s 26ms/step
# Current event:
#   Inside, small room: 0.459
#   Shuffling cards: 0.127
#   Crushing    : 0.072
#   Door        : 0.057
#   Crackle     : 0.053
# 64
# 1/1 [==============================] - 0s 31ms/step
# Current event:
#   Silence     : 0.211
#   Inside, small room: 0.130
#   Inside, large room or hall: 0.041
#   Arrow       : 0.039
#   Speech      : 0.033
# 65
# 1/1 [==============================] - 0s 40ms/step
# Current event:
#   Silence     : 0.824
#   Inside, small room: 0.022
#   Musical instrument: 0.008
#   Violin, fiddle: 0.004
#   Tick        : 0.003
# 66
# 1/1 [==============================] - 0s 21ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 67
# 1/1 [==============================] - 0s 23ms/step
# Current event:
#   Silence     : 0.995
#   Speech      : 0.000
#   Inside, small room: 0.000
#   Narration, monologue: 0.000
#   Music       : 0.000
# 68
# 1/1 [==============================] - 0s 26ms/step
# Current event:
#   Inside, small room: 0.245
#   Glass       : 0.124
#   Ping        : 0.112
#   Tick        : 0.081
#   Door        : 0.080
# 69
# 1/1 [==============================] - 0s 19ms/step
# Current event:
#   Silence     : 0.322
#   Inside, small room: 0.180
#   Clicking    : 0.023
#   Speech      : 0.023
#   Tick        : 0.009
# 70
# 1/1 [==============================] - 0s 21ms/step
# Current event:
#   Door        : 0.142
#   Wood        : 0.117
#   Inside, small room: 0.105
#   Silence     : 0.102
#   Tap         : 0.079
# 71
# 1/1 [==============================] - 0s 20ms/step
# Current event:
#   Silence     : 0.999
#   Speech      : 0.001
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 72
# 1/1 [==============================] - 0s 23ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Inside, small room: 0.000
#   Narration, monologue: 0.000
# 73
# 1/1 [==============================] - 0s 67ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Inside, small room: 0.000
#   Narration, monologue: 0.000
# 74
# 1/1 [==============================] - 0s 53ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Inside, small room: 0.000
#   Narration, monologue: 0.000
# 75
# 1/1 [==============================] - 0s 48ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Narration, monologue: 0.000
#   Inside, small room: 0.000
# 76
# 1/1 [==============================] - 0s 175ms/step
# Current event:
#   Silence     : 0.622
#   Inside, small room: 0.042
#   Speech      : 0.033
#   Clicking    : 0.016
#   Tap         : 0.005
# 77
# 1/1 [==============================] - 0s 413ms/step
# Current event:
#   Silence     : 1.000
#   Speech      : 0.000
#   Music       : 0.000
#   Inside, small room: 0.000
#   Narration, monologue: 0.000
# 78
# 1/1 [==============================] - 0s 42ms/step
# Current event:
#   Silence     : 0.999
#   Speech      : 0.000
#   Inside, small room: 0.000
#   Narration, monologue: 0.000
#   Musical instrument: 0.000
# 79
# 1/1 [==============================] - 0s 34ms/step
# Current event:
#   Music       : 0.266
#   Television  : 0.035
#   Livestock, farm animals, working animals: 0.024
#   Inside, small room: 0.023
#   Animal      : 0.015
# 80
# 1/1 [==============================] - 0s 26ms/step
# Current event:
#   Music       : 0.953
#   Folk music  : 0.045
#   Traditional music: 0.041
#   Music of Asia: 0.035
#   Music of Bollywood: 0.031
# 81
# 1/1 [==============================] - 0s 24ms/step
# Current event:
#   Music       : 0.992
#   Folk music  : 0.016
#   Musical instrument: 0.010
#   Traditional music: 0.008
#   Middle Eastern music: 0.003
# 82
# 1/1 [==============================] - 0s 59ms/step
# Current event:
#   Music       : 0.997
#   Folk music  : 0.019
#   Musical instrument: 0.016
#   Middle Eastern music: 0.008
#   Music of Bollywood: 0.008
# 83
# 1/1 [==============================] - 0s 22ms/step
# Current event:
#   Music       : 0.965
#   Folk music  : 0.065
#   Traditional music: 0.063
#   Music of Bollywood: 0.018
#   Music of Asia: 0.010
# 84
# 1/1 [==============================] - 0s 71ms/step
# Current event:
#   Music       : 0.981
#   Electronic music: 0.003
#   Singing     : 0.003
#   Soundtrack music: 0.002
#   Music of Asia: 0.002
# 85
# 1/1 [==============================] - 0s 29ms/step
# Current event:
#   Music       : 0.901
#   Music of Asia: 0.143
#   Music of Bollywood: 0.058
#   Folk music  : 0.017
#   Singing     : 0.013
# 86
# 1/1 [==============================] - 0s 41ms/step
# Current event:
#   Music       : 0.974
#   Musical instrument: 0.010
#   Electronic music: 0.009
#   Techno      : 0.008
#   Harpsichord : 0.005
# 87
# 1/1 [==============================] - 0s 63ms/step
# Current event:
#   Music       : 0.996
#   Techno      : 0.008
#   Folk music  : 0.005
#   Electronic music: 0.004
#   Singing     : 0.003
# 88
# 1/1 [==============================] - 0s 199ms/step
# Current event:
#   Music       : 0.978
#   Guitar      : 0.006
#   Electric guitar: 0.005
#   Rock and roll: 0.005
#   Strum       : 0.005
# 89
# 1/1 [==============================] - 0s 32ms/step
# Current event:
#   Music       : 0.824
#   Folk music  : 0.120
#   Middle Eastern music: 0.051
#   Traditional music: 0.030
#   Singing     : 0.026
# 90
# 1/1 [==============================] - 0s 26ms/step
# Current event:
#   Music       : 0.961
#   Music of Asia: 0.057
#   Music of Bollywood: 0.031
#   Singing     : 0.014
#   Pop music   : 0.007
# 91
# 1/1 [==============================] - 0s 26ms/step
# Current event:
#   Music       : 0.963
#   Singing     : 0.007
#   Music for children: 0.004
#   Inside, small room: 0.002
#   Pop music   : 0.002
# 92
# 1/1 [==============================] - 0s 64ms/step
# Current event:
#   Music       : 0.931
#   Music of Bollywood: 0.168
#   Music of Asia: 0.109
#   Folk music  : 0.072
#   Singing     : 0.015
# 93
# 1/1 [==============================] - 0s 22ms/step
# Current event:
#   Music       : 0.940
#   Music of Bollywood: 0.042
#   Music of Asia: 0.032
#   Folk music  : 0.031
#   Singing     : 0.029
# 94
# 1/1 [==============================] - 0s 23ms/step
# Current event:
#   Music       : 0.844
#   Folk music  : 0.046
#   Music of Asia: 0.020
#   Traditional music: 0.020
#   Singing     : 0.014
# 95
# 1/1 [==============================] - 0s 30ms/step
# Current event:
#   Music       : 0.881
#   Music of Bollywood: 0.103
#   Folk music  : 0.068
#   Music of Asia: 0.064
#   Singing     : 0.026
# 96
# 1/1 [==============================] - 0s 33ms/step
# Current event:
#   Music       : 0.890
#   Singing     : 0.030
#   Synthetic singing: 0.017
#   Music of Asia: 0.010
#   Music for children: 0.009
# 97
# 1/1 [==============================] - 0s 69ms/step
# Current event:
#   Music       : 0.915
#   Music of Bollywood: 0.169
#   Music of Asia: 0.164
#   Folk music  : 0.056
#   Singing     : 0.020
# 98
# 1/1 [==============================] - 0s 38ms/step
# Current event:
#   Inside, small room: 0.514
#   Speech      : 0.091
#   Domestic animals, pets: 0.021
#   Writing     : 0.016
#   Inside, large room or hall: 0.014
# 99
# 1/1 [==============================] - 0s 26ms/step
# Current event:
#   Clip-clop   : 0.217
#   Walk, footsteps: 0.150
#   Run         : 0.141
#   Horse       : 0.130
#   Fire        : 0.084
# 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 26
#      23 plt.ion()
#      24 while True:
#      25     # data read
# ---> 26     data = stream.read(frame_len, exception_on_overflow=False)
#      28     # byte --> float
#      29     frame_data = librosa.util.buf_to_float(data, n_bytes=2, dtype=np.int16)
#
# File ~/anaconda3/envs/new_env/lib/python3.8/site-packages/pyaudio/__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
