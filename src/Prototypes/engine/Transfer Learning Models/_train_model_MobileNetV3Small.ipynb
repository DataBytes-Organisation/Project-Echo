# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
os.chdir(
    "C:\\Users\\ptanmay143\\Data\\Projects\\project-echo/src/Prototypes/engine/Transfer Learning Models"
)

# %%
from _model_config import *

# %%
# %pip install diskcache -q
# %pip install audiomentations==0.29.0 -q
# %pip install tensorflow==2.10.0 -q
# %pip install keras==2.10.0 -q
# %pip install tensorflow_addons -q

# %%
exec(f"from {MODEL_NAME} import *")
# Out:
# Python Version           :  3.8.16
# TensorFlow Version       :  2.10.1
# Keras Version            :  2.10.0
# Librosa Version          :  0.10.1
# Audiomentations Version  :  0.35.0
# vram limit set to 4096MB
# Found 7514 files belonging to 118 classes.
# Class names:  ['Acanthiza chrysorrhoa', 'Acanthiza lineata', 'Acanthiza nana', 'Acanthiza pusilla', 'Acanthiza reguloides', 'Acanthiza uropygialis', 'Acanthorhynchus tenuirostris', 'Accipiter cirrocephalus', 'Aidemosyne modesta', 'Alauda arvensis', 'Anhinga novaehollandiae', 'Anthochaera phrygia', 'Antigone rubicunda', 'Artamus cinereus', 'Artamus cyanopterus', 'Artamus minor', 'Artamus superciliosus', 'Barnardius zonarius', 'Callocephalon fimbriatum', 'Calyptorhynchus banksii', 'Calyptorhynchus lathami', 'Capra Hircus', 'Carduelis carduelis', 'Carterornis leucotis', 'Cervus Unicolour', 'Ceyx azureus', 'Chenonetta jubata', 'Chlamydera nuchalis', 'Cincloramphus mathewsi', 'Cinclosoma punctatum', 'Cisticola exilis', 'Climacteris picumnus', 'Colluricincla harmonica', 'Conopophila albogularis', 'Cophixalus exiguus', 'Cophixalus infacetus', 'Cophixalus ornatus', 'Coracina novaehollandiae', 'Coracina papuensis', 'Corcorax melanorhamphos', 'Cormobates leucophaea', 'Corvus mellori', 'Coturnix pectoralis', 'Cygnus atratus', 'Dama Dama', 'Daphoenositta chrysoptera', 'Dasyurus maculatus', 'Dicaeum hirundinaceum', 'Egretta novaehollandiae', 'Elseyornis melanops', 'Entomyzon cyanotis', 'Eurostopodus argus', 'Eurostopodus mystacalis', 'Eurystomus orientalis', 'Falco berigora', 'Falco cenchroides', 'Falco peregrinus', 'Falcunculus frontatus', 'Felis Catus', 'Fulica atra', 'Gallinula tenebrosa', 'Geopelia cuneata', 'Gerygone mouki', 'Haliastur sphenurus', 'Irediparra gallinacea', 'Lalage leucomela', 'Litoria inermis', 'Manorina melanophrys', 'Megapodius reinwardt', 'Melithreptus brevirostris', 'Melithreptus gularis', 'Melithreptus lunatus', 'Microeca flavigaster', 'Neophema pulchella', 'Nesoptilotis leucotis', 'Pachycephala simplex', 'Pardalotus rubricatus', 'Parvipsitta pusilla', 'Pelecanus conspicillatus', 'Petrochelidon ariel', 'Petrochelidon nigricans', 'Petroica boodang', 'Petroica goodenovii', 'Petroica phoenicea', 'Petroica rosea', 'Pezoporus wallicus', 'Phaps elegans', 'Philemon citreogularis', 'Philemon corniculatus', 'Phylidonyris niger', 'Pitta iris', 'Pitta versicolor', 'Platycercus elegans', 'Plectorhyncha lanceolata', 'Psophodes cristatus', 'Ptilinopus regina', 'Pycnoptilus floccosus', 'Ramsayornis fasciatus', 'Ranoidea caerulea', 'Rattus Norvegicus', 'Rhinella marina', 'Rhipidura albiscapa', 'Rhipidura leucophrys', 'Rhipidura rufifrons', 'Rhipidura rufiventris', 'Scythrops novaehollandiae', 'Spilopelia chinensis', 'Stizoptera bichenovii', 'Stomiopera unicolor', 'Strepera versicolor', 'Sus Scrofa', 'Symposiachrus trivirgatus', 'Tregellasia capito', 'Trichosurus vulpecula', 'Uperoleia altissima', 'Uperoleia mimula', 'Vanellus miles', 'Vulpes vulpes']
# Training dataset length: 6011
# Validation dataset length: 1427
# Test dataset length: 76

# %%
train_model(True)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]     0         Y
#
#  MobilenetV3small (Functiona  (None, 10, 10, 576)      939120    Y
#  l)
#
#  global_average_pooling2d (G  (None, 576)              0         Y
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 576)               0         Y
#
#  dense (Dense)               (None, 118)               68086     Y
#
# ============================================================================
# Total params: 1,007,206
# Trainable params: 995,094
# Non-trainable params: 12,112
# ____________________________________________________________________________
# Epoch 1/5000
# 376/376 [==============================] - 537s 1s/step - loss: 4.1753 - accuracy: 0.0697 - val_loss: 4.0473 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 2/5000
# 376/376 [==============================] - 484s 1s/step - loss: 4.0471 - accuracy: 0.0739 - val_loss: 4.0218 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 3/5000
# 376/376 [==============================] - 478s 1s/step - loss: 4.0434 - accuracy: 0.0790 - val_loss: 4.0198 - val_accuracy: 0.0932 - lr: 1.0000e-04
# Epoch 4/5000
# 376/376 [==============================] - 463s 1s/step - loss: 4.0322 - accuracy: 0.0794 - val_loss: 4.0312 - val_accuracy: 0.0932 - lr: 1.0000e-04
# Epoch 5/5000
# 376/376 [==============================] - 440s 1s/step - loss: 4.0220 - accuracy: 0.0822 - val_loss: 4.0240 - val_accuracy: 0.0932 - lr: 1.0000e-04
# Epoch 6/5000
# 376/376 [==============================] - 444s 1s/step - loss: 4.0191 - accuracy: 0.0830 - val_loss: 4.0280 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 7/5000
# 376/376 [==============================] - 409s 1s/step - loss: 4.0209 - accuracy: 0.0787 - val_loss: 4.0185 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 8/5000
# 376/376 [==============================] - 393s 1s/step - loss: 4.0201 - accuracy: 0.0830 - val_loss: 4.0364 - val_accuracy: 0.0575 - lr: 1.0000e-04
# Epoch 9/5000
# 376/376 [==============================] - 383s 1s/step - loss: 4.0155 - accuracy: 0.0822 - val_loss: 4.0229 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 10/5000
# 376/376 [==============================] - 363s 963ms/step - loss: 4.0133 - accuracy: 0.0757 - val_loss: 4.0243 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 11/5000
# 376/376 [==============================] - 349s 925ms/step - loss: 4.0153 - accuracy: 0.0810 - val_loss: 4.0115 - val_accuracy: 0.0932 - lr: 1.0000e-04
# Epoch 12/5000
# 376/376 [==============================] - 330s 876ms/step - loss: 4.0143 - accuracy: 0.0804 - val_loss: 4.0174 - val_accuracy: 0.0932 - lr: 1.0000e-04
# Epoch 13/5000
# 376/376 [==============================] - 301s 799ms/step - loss: 4.0115 - accuracy: 0.0807 - val_loss: 4.0185 - val_accuracy: 0.0715 - lr: 1.0000e-04
# Epoch 14/5000
# 376/376 [==============================] - 364s 968ms/step - loss: 4.0110 - accuracy: 0.0790 - val_loss: 4.0261 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 15/5000
# 376/376 [==============================] - 339s 899ms/step - loss: 4.0128 - accuracy: 0.0802 - val_loss: 4.0244 - val_accuracy: 0.0932 - lr: 1.0000e-04
# Epoch 16/5000
# 376/376 [==============================] - 325s 864ms/step - loss: 4.0110 - accuracy: 0.0843 - val_loss: 4.0197 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 17/5000
# 376/376 [==============================] - 314s 833ms/step - loss: 4.0096 - accuracy: 0.0847 - val_loss: 4.0115 - val_accuracy: 0.0932 - lr: 1.0000e-04
# Epoch 18/5000
# 376/376 [==============================] - 301s 800ms/step - loss: 4.0136 - accuracy: 0.0832 - val_loss: 4.0203 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 19/5000
# 376/376 [==============================] - ETA: 0s - loss: 4.0093 - accuracy: 0.0842
# Epoch 19: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-05.
# 376/376 [==============================] - 280s 741ms/step - loss: 4.0093 - accuracy: 0.0842 - val_loss: 4.0226 - val_accuracy: 0.0736 - lr: 1.0000e-04
# Epoch 20/5000
# 376/376 [==============================] - 273s 725ms/step - loss: 4.0048 - accuracy: 0.0765 - val_loss: 4.0136 - val_accuracy: 0.0736 - lr: 7.5000e-05
# Epoch 21/5000
# 376/376 [==============================] - 272s 722ms/step - loss: 4.0054 - accuracy: 0.0823 - val_loss: 4.0183 - val_accuracy: 0.0715 - lr: 7.5000e-05
# Epoch 22/5000
# 376/376 [==============================] - 233s 619ms/step - loss: 4.0053 - accuracy: 0.0825 - val_loss: 4.0199 - val_accuracy: 0.0736 - lr: 7.5000e-05
# Epoch 23/5000
# 376/376 [==============================] - 237s 627ms/step - loss: 4.0074 - accuracy: 0.0782 - val_loss: 4.0155 - val_accuracy: 0.0932 - lr: 7.5000e-05
# Epoch 24/5000
# 376/376 [==============================] - 192s 509ms/step - loss: 4.0024 - accuracy: 0.0769 - val_loss: 4.0143 - val_accuracy: 0.0932 - lr: 7.5000e-05
# Epoch 25/5000
# 376/376 [==============================] - 186s 496ms/step - loss: 4.0051 - accuracy: 0.0782 - val_loss: 4.0147 - val_accuracy: 0.0932 - lr: 7.5000e-05
# Epoch 26/5000
# 376/376 [==============================] - 221s 583ms/step - loss: 4.0028 - accuracy: 0.0807 - val_loss: 4.0148 - val_accuracy: 0.0736 - lr: 7.5000e-05
# Epoch 27/5000
# 376/376 [==============================] - ETA: 0s - loss: 4.0040 - accuracy: 0.0837
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.6249997214763425e-05.
# 376/376 [==============================] - 187s 496ms/step - loss: 4.0040 - accuracy: 0.0837 - val_loss: 4.0194 - val_accuracy: 0.0932 - lr: 7.5000e-05
# Epoch 28/5000
# 376/376 [==============================] - 189s 499ms/step - loss: 4.0044 - accuracy: 0.0825 - val_loss: 4.0132 - val_accuracy: 0.0932 - lr: 5.6250e-05
# Epoch 29/5000
# 376/376 [==============================] - 178s 470ms/step - loss: 4.0040 - accuracy: 0.0799 - val_loss: 4.0153 - val_accuracy: 0.0932 - lr: 5.6250e-05
# Epoch 30/5000
# 376/376 [==============================] - 180s 476ms/step - loss: 4.0035 - accuracy: 0.0840 - val_loss: 4.0155 - val_accuracy: 0.0736 - lr: 5.6250e-05
# Epoch 31/5000
# 376/376 [==============================] - 176s 467ms/step - loss: 4.0015 - accuracy: 0.0843 - val_loss: 4.0161 - val_accuracy: 0.0736 - lr: 5.6250e-05
# Epoch 32/5000
# 376/376 [==============================] - 166s 440ms/step - loss: 4.0039 - accuracy: 0.0840 - val_loss: 4.0148 - val_accuracy: 0.0932 - lr: 5.6250e-05
# Epoch 33/5000
# 376/376 [==============================] - 160s 424ms/step - loss: 4.0010 - accuracy: 0.0875 - val_loss: 4.0135 - val_accuracy: 0.0932 - lr: 5.6250e-05
# Model Training Time: 10152.826652288437 seconds
# Model Training Time: 169.21 minutes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MobileNetV3Small/assets
# INFO:tensorflow:Assets written to: models/MobileNetV3Small/assets
