# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
os.chdir(
    "C:\\Users\\ptanmay143\\Data\\Projects\\project-echo/src/Prototypes/engine/Transfer Learning Models"
)

# %%
from _model_config import *

# %%
# %pip install diskcache -q
# %pip install audiomentations==0.29.0 -q
# %pip install tensorflow==2.10.0 -q
# %pip install keras==2.10.0 -q
# %pip install tensorflow_addons -q

# %%
exec(f"from {MODEL_NAME} import *")
# Out:
# Python Version           :  3.8.16
# TensorFlow Version       :  2.10.1
# Keras Version            :  2.10.0
# Librosa Version          :  0.10.1
# Audiomentations Version  :  0.35.0
# vram limit set to 4096MB
# Found 7514 files belonging to 118 classes.
# Class names:  ['Acanthiza chrysorrhoa', 'Acanthiza lineata', 'Acanthiza nana', 'Acanthiza pusilla', 'Acanthiza reguloides', 'Acanthiza uropygialis', 'Acanthorhynchus tenuirostris', 'Accipiter cirrocephalus', 'Aidemosyne modesta', 'Alauda arvensis', 'Anhinga novaehollandiae', 'Anthochaera phrygia', 'Antigone rubicunda', 'Artamus cinereus', 'Artamus cyanopterus', 'Artamus minor', 'Artamus superciliosus', 'Barnardius zonarius', 'Callocephalon fimbriatum', 'Calyptorhynchus banksii', 'Calyptorhynchus lathami', 'Capra Hircus', 'Carduelis carduelis', 'Carterornis leucotis', 'Cervus Unicolour', 'Ceyx azureus', 'Chenonetta jubata', 'Chlamydera nuchalis', 'Cincloramphus mathewsi', 'Cinclosoma punctatum', 'Cisticola exilis', 'Climacteris picumnus', 'Colluricincla harmonica', 'Conopophila albogularis', 'Cophixalus exiguus', 'Cophixalus infacetus', 'Cophixalus ornatus', 'Coracina novaehollandiae', 'Coracina papuensis', 'Corcorax melanorhamphos', 'Cormobates leucophaea', 'Corvus mellori', 'Coturnix pectoralis', 'Cygnus atratus', 'Dama Dama', 'Daphoenositta chrysoptera', 'Dasyurus maculatus', 'Dicaeum hirundinaceum', 'Egretta novaehollandiae', 'Elseyornis melanops', 'Entomyzon cyanotis', 'Eurostopodus argus', 'Eurostopodus mystacalis', 'Eurystomus orientalis', 'Falco berigora', 'Falco cenchroides', 'Falco peregrinus', 'Falcunculus frontatus', 'Felis Catus', 'Fulica atra', 'Gallinula tenebrosa', 'Geopelia cuneata', 'Gerygone mouki', 'Haliastur sphenurus', 'Irediparra gallinacea', 'Lalage leucomela', 'Litoria inermis', 'Manorina melanophrys', 'Megapodius reinwardt', 'Melithreptus brevirostris', 'Melithreptus gularis', 'Melithreptus lunatus', 'Microeca flavigaster', 'Neophema pulchella', 'Nesoptilotis leucotis', 'Pachycephala simplex', 'Pardalotus rubricatus', 'Parvipsitta pusilla', 'Pelecanus conspicillatus', 'Petrochelidon ariel', 'Petrochelidon nigricans', 'Petroica boodang', 'Petroica goodenovii', 'Petroica phoenicea', 'Petroica rosea', 'Pezoporus wallicus', 'Phaps elegans', 'Philemon citreogularis', 'Philemon corniculatus', 'Phylidonyris niger', 'Pitta iris', 'Pitta versicolor', 'Platycercus elegans', 'Plectorhyncha lanceolata', 'Psophodes cristatus', 'Ptilinopus regina', 'Pycnoptilus floccosus', 'Ramsayornis fasciatus', 'Ranoidea caerulea', 'Rattus Norvegicus', 'Rhinella marina', 'Rhipidura albiscapa', 'Rhipidura leucophrys', 'Rhipidura rufifrons', 'Rhipidura rufiventris', 'Scythrops novaehollandiae', 'Spilopelia chinensis', 'Stizoptera bichenovii', 'Stomiopera unicolor', 'Strepera versicolor', 'Sus Scrofa', 'Symposiachrus trivirgatus', 'Tregellasia capito', 'Trichosurus vulpecula', 'Uperoleia altissima', 'Uperoleia mimula', 'Vanellus miles', 'Vulpes vulpes']
# Training dataset length: 6011
# Validation dataset length: 1427
# Test dataset length: 76

# %%
train_model(True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 10s 0us/step
# Model: "model"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]     0         Y
#
#  resnet50v2 (Functional)     (None, 10, 10, 2048)      23564800  Y
#
#  global_average_pooling2d (G  (None, 2048)             0         Y
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0         Y
#
#  dense (Dense)               (None, 118)               241782    Y
#
# ============================================================================
# Total params: 23,806,582
# Trainable params: 23,761,142
# Non-trainable params: 45,440
# ____________________________________________________________________________
# Epoch 1/5000
# 376/376 [==============================] - 860s 2s/step - loss: 3.6290 - accuracy: 0.1998 - val_loss: 2.6427 - val_accuracy: 0.3924 - lr: 1.0000e-04
# Epoch 2/5000
# 376/376 [==============================] - 925s 2s/step - loss: 2.2486 - accuracy: 0.4686 - val_loss: 1.6247 - val_accuracy: 0.5985 - lr: 1.0000e-04
# Epoch 3/5000
# 376/376 [==============================] - 860s 2s/step - loss: 1.5264 - accuracy: 0.6165 - val_loss: 1.3500 - val_accuracy: 0.6454 - lr: 1.0000e-04
# Epoch 4/5000
# 376/376 [==============================] - 802s 2s/step - loss: 1.1260 - accuracy: 0.7085 - val_loss: 1.1097 - val_accuracy: 0.7323 - lr: 1.0000e-04
# Epoch 5/5000
# 376/376 [==============================] - 790s 2s/step - loss: 0.8901 - accuracy: 0.7629 - val_loss: 0.9137 - val_accuracy: 0.7554 - lr: 1.0000e-04
# Epoch 6/5000
# 376/376 [==============================] - 750s 2s/step - loss: 0.6704 - accuracy: 0.8172 - val_loss: 0.9477 - val_accuracy: 0.7715 - lr: 1.0000e-04
# Epoch 7/5000
# 376/376 [==============================] - 708s 2s/step - loss: 0.5483 - accuracy: 0.8476 - val_loss: 0.8379 - val_accuracy: 0.8031 - lr: 1.0000e-04
# Epoch 8/5000
# 376/376 [==============================] - 663s 2s/step - loss: 0.4682 - accuracy: 0.8692 - val_loss: 0.8115 - val_accuracy: 0.8136 - lr: 1.0000e-04
# Epoch 9/5000
# 376/376 [==============================] - 731s 2s/step - loss: 0.4332 - accuracy: 0.8761 - val_loss: 0.7028 - val_accuracy: 0.8353 - lr: 1.0000e-04
# Epoch 10/5000
# 376/376 [==============================] - 643s 2s/step - loss: 0.3394 - accuracy: 0.9040 - val_loss: 0.8343 - val_accuracy: 0.8136 - lr: 1.0000e-04
# Epoch 11/5000
# 376/376 [==============================] - 595s 2s/step - loss: 0.3290 - accuracy: 0.9093 - val_loss: 0.7639 - val_accuracy: 0.8332 - lr: 1.0000e-04
# Epoch 12/5000
# 376/376 [==============================] - 583s 2s/step - loss: 0.2544 - accuracy: 0.9296 - val_loss: 0.7358 - val_accuracy: 0.8493 - lr: 1.0000e-04
# Epoch 13/5000
# 376/376 [==============================] - 541s 1s/step - loss: 0.2746 - accuracy: 0.9208 - val_loss: 0.7564 - val_accuracy: 0.8395 - lr: 1.0000e-04
# Epoch 14/5000
# 376/376 [==============================] - 536s 1s/step - loss: 0.2104 - accuracy: 0.9361 - val_loss: 0.6731 - val_accuracy: 0.8444 - lr: 1.0000e-04
# Epoch 15/5000
# 376/376 [==============================] - 516s 1s/step - loss: 0.2396 - accuracy: 0.9286 - val_loss: 0.7519 - val_accuracy: 0.8360 - lr: 1.0000e-04
# Epoch 16/5000
# 376/376 [==============================] - 455s 1s/step - loss: 0.2085 - accuracy: 0.9421 - val_loss: 0.6571 - val_accuracy: 0.8577 - lr: 1.0000e-04
# Epoch 17/5000
# 376/376 [==============================] - 452s 1s/step - loss: 0.2082 - accuracy: 0.9376 - val_loss: 0.8472 - val_accuracy: 0.8346 - lr: 1.0000e-04
# Epoch 18/5000
# 376/376 [==============================] - 426s 1s/step - loss: 0.1543 - accuracy: 0.9538 - val_loss: 0.7661 - val_accuracy: 0.8248 - lr: 1.0000e-04
# Epoch 19/5000
# 376/376 [==============================] - 414s 1s/step - loss: 0.1744 - accuracy: 0.9491 - val_loss: 0.7370 - val_accuracy: 0.8514 - lr: 1.0000e-04
# Epoch 20/5000
# 376/376 [==============================] - 406s 1s/step - loss: 0.1735 - accuracy: 0.9498 - val_loss: 0.6015 - val_accuracy: 0.8697 - lr: 1.0000e-04
# Epoch 21/5000
# 376/376 [==============================] - 402s 1s/step - loss: 0.1459 - accuracy: 0.9577 - val_loss: 0.8092 - val_accuracy: 0.8542 - lr: 1.0000e-04
# Epoch 22/5000
# 376/376 [==============================] - 374s 994ms/step - loss: 0.1594 - accuracy: 0.9547 - val_loss: 0.7078 - val_accuracy: 0.8563 - lr: 1.0000e-04
# Epoch 23/5000
# 376/376 [==============================] - 354s 939ms/step - loss: 0.1491 - accuracy: 0.9589 - val_loss: 0.7071 - val_accuracy: 0.8584 - lr: 1.0000e-04
# Epoch 24/5000
# 376/376 [==============================] - 326s 864ms/step - loss: 0.1388 - accuracy: 0.9622 - val_loss: 0.6307 - val_accuracy: 0.8697 - lr: 1.0000e-04
# Epoch 25/5000
# 376/376 [==============================] - 317s 840ms/step - loss: 0.1322 - accuracy: 0.9656 - val_loss: 0.7521 - val_accuracy: 0.8444 - lr: 1.0000e-04
# Epoch 26/5000
# 376/376 [==============================] - 309s 820ms/step - loss: 0.1421 - accuracy: 0.9576 - val_loss: 0.6703 - val_accuracy: 0.8563 - lr: 1.0000e-04
# Epoch 27/5000
# 376/376 [==============================] - 294s 781ms/step - loss: 0.1368 - accuracy: 0.9609 - val_loss: 0.6307 - val_accuracy: 0.8549 - lr: 1.0000e-04
# Epoch 28/5000
# 376/376 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9656
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-05.
# 376/376 [==============================] - 292s 771ms/step - loss: 0.1192 - accuracy: 0.9656 - val_loss: 0.7583 - val_accuracy: 0.8521 - lr: 1.0000e-04
# Epoch 29/5000
# 376/376 [==============================] - 282s 749ms/step - loss: 0.0691 - accuracy: 0.9779 - val_loss: 0.7683 - val_accuracy: 0.8535 - lr: 7.5000e-05
# Epoch 30/5000
# 376/376 [==============================] - 263s 695ms/step - loss: 0.0766 - accuracy: 0.9785 - val_loss: 0.6666 - val_accuracy: 0.8795 - lr: 7.5000e-05
# Epoch 31/5000
# 376/376 [==============================] - 253s 669ms/step - loss: 0.0650 - accuracy: 0.9789 - val_loss: 0.6684 - val_accuracy: 0.8711 - lr: 7.5000e-05
# Epoch 32/5000
# 376/376 [==============================] - 267s 705ms/step - loss: 0.0663 - accuracy: 0.9817 - val_loss: 0.7397 - val_accuracy: 0.8697 - lr: 7.5000e-05
# Epoch 33/5000
# 376/376 [==============================] - 240s 636ms/step - loss: 0.0644 - accuracy: 0.9809 - val_loss: 0.9084 - val_accuracy: 0.8346 - lr: 7.5000e-05
# Epoch 34/5000
# 376/376 [==============================] - 231s 611ms/step - loss: 0.0776 - accuracy: 0.9777 - val_loss: 0.7185 - val_accuracy: 0.8486 - lr: 7.5000e-05
# Epoch 35/5000
# 376/376 [==============================] - 218s 579ms/step - loss: 0.0706 - accuracy: 0.9802 - val_loss: 0.6633 - val_accuracy: 0.8781 - lr: 7.5000e-05
# Epoch 36/5000
# 376/376 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9814
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.6249997214763425e-05.
# 376/376 [==============================] - 222s 585ms/step - loss: 0.0652 - accuracy: 0.9814 - val_loss: 0.6360 - val_accuracy: 0.8732 - lr: 7.5000e-05
# Model Training Time: 17307.432111263275 seconds
# Model Training Time: 288.46 minutes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/ResNet50V2/assets
# INFO:tensorflow:Assets written to: models/ResNet50V2/assets
