# %%
import os
import librosa
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer

np.complex = complex

# only for audio files (mp3 and wav)
audio_dir = r"C:\Users\User\Downloads\Animal Sounds 5\Animal Sounds"
supported_exts = ['.mp3', '.wav']

# For training
spectrograms = []
types = []
sub_categories = []

# Parse labels: "Type - Subcategory" OR fallback
def parse_labels_from_filename(filename):
    name = os.path.splitext(filename)[0]

    if '-' in name:
        first_dash = name.find('-')
        type_part = name[:first_dash].strip().lower()
        sub_part = name[first_dash + 1:].strip()
        return type_part if type_part else 'unknown', sub_part
    else:
        # No dash? Use fallback logic
        tokens = name.split()
        if len(tokens) >= 2:
            return tokens[0].strip().lower(), ' '.join(tokens[1:]).strip()
        else:
            return 'unknown', name.strip()

# Load audio files and convert to spectrograms
for fname in os.listdir(audio_dir):
    if any(fname.lower().endswith(ext) for ext in supported_exts):
        path = os.path.join(audio_dir, fname)
        try:
            y, sr = librosa.load(path, sr=22050)
            S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
            S_DB = librosa.power_to_db(S, ref=np.max)

            if S_DB.shape[1] < 128:
                pad = 128 - S_DB.shape[1]
                S_DB = np.pad(S_DB, ((0, 0), (0, pad)), mode='constant')
            elif S_DB.shape[1] > 128:
                S_DB = S_DB[:, :128]

            spectrograms.append(S_DB)

            t, sub = parse_labels_from_filename(fname)
            if not t:
                print(f"⚠️ Empty type parsed from: {fname}")
            types.append([t])
            sub_categories.append([sub])

        except Exception as e:
            print(f"⚠️ Skipped {fname}: {e}")



# Convert to numpy arrays
spectrograms = np.expand_dims(np.array(spectrograms), -1)

# Labels one-hot encoding
mlb_types = MultiLabelBinarizer()
mlb_sub_categories = MultiLabelBinarizer()
y_types = mlb_types.fit_transform(types)
y_sub_categories = mlb_sub_categories.fit_transform(sub_categories)

print(f"✅ Loaded {len(spectrograms)} spectrograms")
print("Example labels:", types[:3], sub_categories[:3])
# Out:
# ✅ Loaded 32 spectrograms
# Example labels: [['unknown'], ['unknown'], ['australian']] [['Black-Currawong-Strepera-fuliginosa'], ['Kingfisher-Todiramphus sanctus'], ['Magpie-Gymnorhina-tibicen']]

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# Define the CNN model
def create_model(input_shape, num_types, num_sub_categories):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu')(inputs)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)

    type_output = Dense(num_types, activation='sigmoid', name='type_output')(x)
    sub_category_output = Dense(num_sub_categories, activation='sigmoid', name='sub_category_output')(x)

    model = Model(inputs=inputs, outputs=[type_output, sub_category_output])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics={'type_output': 'accuracy', 'sub_category_output': 'accuracy'})
    return model

# Prepare data
input_shape = (128, 128, 1)
num_types = len(mlb_types.classes_)
num_sub_categories = len(mlb_sub_categories.classes_)

X_train, X_val, y_train_types, y_val_types, y_train_sub_categories, y_val_sub_categories = train_test_split(
    spectrograms, y_types, y_sub_categories, test_size=0.2, random_state=42
)

model = create_model(input_shape, num_types, num_sub_categories)

# Train the model
history = model.fit(
    X_train,
    {'type_output': y_train_types, 'sub_category_output': y_train_sub_categories},
    validation_data=(X_val, {'type_output': y_val_types, 'sub_category_output': y_val_sub_categories}),
    epochs=20,
    batch_size=8
)
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\projectecho\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\projectecho\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\projectecho\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\projectecho\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\projectecho\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 4/4 [==============================] - 1s 127ms/step - loss: 9.0467 - type_output_loss: 3.4554 - sub_category_output_loss: 5.5913 - type_output_accuracy: 0.0800 - sub_category_output_accuracy: 0.0400 - val_loss: 1.5218 - val_type_output_loss: 0.7513 - val_sub_category_output_loss: 0.7705 - val_type_output_accuracy: 0.1429 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 2/20
# 4/4 [==============================] - 0s 57ms/step - loss: 1.7106 - type_output_loss: 0.8321 - sub_category_output_loss: 0.8785 - type_output_accuracy: 0.0800 - sub_category_output_accuracy: 0.0800 - val_loss: 0.7107 - val_type_output_loss: 0.3445 - val_sub_category_output_loss: 0.3662 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 3/20
# 4/4 [==============================] - 0s 55ms/step - loss: 0.8372 - type_output_loss: 0.3509 - sub_category_output_loss: 0.4863 - type_output_accuracy: 0.0400 - sub_category_output_accuracy: 0.0000e+00 - val_loss: 0.5190 - val_type_output_loss: 0.2904 - val_sub_category_output_loss: 0.2286 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 4/20
# 4/4 [==============================] - 0s 58ms/step - loss: 0.7519 - type_output_loss: 0.3729 - sub_category_output_loss: 0.3790 - type_output_accuracy: 0.0400 - sub_category_output_accuracy: 0.0800 - val_loss: 0.5534 - val_type_output_loss: 0.2750 - val_sub_category_output_loss: 0.2784 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 5/20
# 4/4 [==============================] - 0s 58ms/step - loss: 0.7254 - type_output_loss: 0.3184 - sub_category_output_loss: 0.4070 - type_output_accuracy: 0.1600 - sub_category_output_accuracy: 0.0800 - val_loss: 0.5296 - val_type_output_loss: 0.2890 - val_sub_category_output_loss: 0.2406 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 6/20
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6346 - type_output_loss: 0.2987 - sub_category_output_loss: 0.3359 - type_output_accuracy: 0.0800 - sub_category_output_accuracy: 0.0800 - val_loss: 0.4882 - val_type_output_loss: 0.2712 - val_sub_category_output_loss: 0.2170 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 7/20
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6409 - type_output_loss: 0.3199 - sub_category_output_loss: 0.3210 - type_output_accuracy: 0.0400 - sub_category_output_accuracy: 0.0800 - val_loss: 0.4748 - val_type_output_loss: 0.2572 - val_sub_category_output_loss: 0.2176 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 8/20
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6467 - type_output_loss: 0.2921 - sub_category_output_loss: 0.3547 - type_output_accuracy: 0.0400 - sub_category_output_accuracy: 0.0400 - val_loss: 0.5237 - val_type_output_loss: 0.2602 - val_sub_category_output_loss: 0.2635 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 9/20
# 4/4 [==============================] - 0s 53ms/step - loss: 0.6173 - type_output_loss: 0.2893 - sub_category_output_loss: 0.3280 - type_output_accuracy: 0.0400 - sub_category_output_accuracy: 0.0400 - val_loss: 0.4866 - val_type_output_loss: 0.2800 - val_sub_category_output_loss: 0.2066 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 10/20
# 4/4 [==============================] - 0s 57ms/step - loss: 0.4733 - type_output_loss: 0.2366 - sub_category_output_loss: 0.2366 - type_output_accuracy: 0.1200 - sub_category_output_accuracy: 0.1200 - val_loss: 0.5074 - val_type_output_loss: 0.3194 - val_sub_category_output_loss: 0.1881 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 11/20
# 4/4 [==============================] - 0s 62ms/step - loss: 0.5052 - type_output_loss: 0.2482 - sub_category_output_loss: 0.2570 - type_output_accuracy: 0.2000 - sub_category_output_accuracy: 0.0000e+00 - val_loss: 0.4534 - val_type_output_loss: 0.2592 - val_sub_category_output_loss: 0.1943 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 12/20
# 4/4 [==============================] - 0s 68ms/step - loss: 0.5766 - type_output_loss: 0.2572 - sub_category_output_loss: 0.3194 - type_output_accuracy: 0.1200 - sub_category_output_accuracy: 0.0000e+00 - val_loss: 0.4830 - val_type_output_loss: 0.2871 - val_sub_category_output_loss: 0.1959 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 13/20
# 4/4 [==============================] - 0s 67ms/step - loss: 0.5253 - type_output_loss: 0.2738 - sub_category_output_loss: 0.2515 - type_output_accuracy: 0.1200 - sub_category_output_accuracy: 0.0400 - val_loss: 0.4893 - val_type_output_loss: 0.2990 - val_sub_category_output_loss: 0.1903 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 14/20
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4830 - type_output_loss: 0.2268 - sub_category_output_loss: 0.2562 - type_output_accuracy: 0.1600 - sub_category_output_accuracy: 0.0000e+00 - val_loss: 0.4468 - val_type_output_loss: 0.2580 - val_sub_category_output_loss: 0.1888 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 15/20
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4710 - type_output_loss: 0.2292 - sub_category_output_loss: 0.2418 - type_output_accuracy: 0.2000 - sub_category_output_accuracy: 0.0000e+00 - val_loss: 0.5042 - val_type_output_loss: 0.3137 - val_sub_category_output_loss: 0.1905 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 16/20
# 4/4 [==============================] - 0s 75ms/step - loss: 0.4587 - type_output_loss: 0.2336 - sub_category_output_loss: 0.2251 - type_output_accuracy: 0.0400 - sub_category_output_accuracy: 0.1200 - val_loss: 0.4404 - val_type_output_loss: 0.2572 - val_sub_category_output_loss: 0.1832 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 17/20
# 4/4 [==============================] - 0s 76ms/step - loss: 0.4421 - type_output_loss: 0.2250 - sub_category_output_loss: 0.2171 - type_output_accuracy: 0.2000 - sub_category_output_accuracy: 0.0400 - val_loss: 0.4620 - val_type_output_loss: 0.2780 - val_sub_category_output_loss: 0.1840 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 18/20
# 4/4 [==============================] - 0s 74ms/step - loss: 0.3924 - type_output_loss: 0.1847 - sub_category_output_loss: 0.2077 - type_output_accuracy: 0.2400 - sub_category_output_accuracy: 0.0000e+00 - val_loss: 0.5232 - val_type_output_loss: 0.3245 - val_sub_category_output_loss: 0.1987 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 19/20
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4469 - type_output_loss: 0.2489 - sub_category_output_loss: 0.1980 - type_output_accuracy: 0.1600 - sub_category_output_accuracy: 0.0800 - val_loss: 0.4553 - val_type_output_loss: 0.2776 - val_sub_category_output_loss: 0.1777 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00
# Epoch 20/20
# 4/4 [==============================] - 0s 74ms/step - loss: 0.3975 - type_output_loss: 0.2038 - sub_category_output_loss: 0.1937 - type_output_accuracy: 0.1600 - sub_category_output_accuracy: 0.0800 - val_loss: 0.5054 - val_type_output_loss: 0.3134 - val_sub_category_output_loss: 0.1920 - val_type_output_accuracy: 0.0000e+00 - val_sub_category_output_accuracy: 0.0000e+00

# %%
import json

# Construct full dataset list
training_data = []
audio_files = os.listdir(audio_dir)

for fname, t_list, s_list in zip(audio_files, types, sub_categories):
    if any(fname.lower().endswith(ext) for ext in supported_exts):
        training_data.append({
            "file": fname,
            "type": t_list[0],
            "sub_category": s_list[0]
        })

# Output path
output_path = os.path.join(audio_dir, "training_data.json")

# Save as JSON
with open(output_path, "w") as f:
    json.dump(training_data, f, indent=4)

print(f"✅ Saved training data to: {output_path}")
# Out:
# ✅ Saved training data to: C:\Users\User\Downloads\Animal Sounds 5\Animal Sounds\training_data.json
