# %% [markdown]
# Overview
#
# Author: stephankokkas
#
# This notebook defines a pipeline that tasks an input directory of audio files and converts them to images using mel-spectrogram transofrmation and preprocessing techniques.

# %%
# disable warnings to tidy up output
import warnings
warnings.filterwarnings("ignore")

# some basic libraries 
from platform import python_version
#import pandas as pd
#import seaborn as sns
import numpy as np
import os
import random
from os import listdir
from os.path import isfile, join


# plot support
import matplotlib.pyplot as plt

# tensorflow support
import tensorflow as tf
#import tensorflow_transform as tft
#import tensorflow_io as tfio
#from tensorflow.contrib.framework.python.ops import audio_ops

# scipy
import scipy

# turn off tensorflow warnings
tf.get_logger().setLevel('ERROR')

# turn off absl warnings
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# print system information
print('Python Version     : ', python_version())
print('TensorFlow Version : ', tf.__version__)
# Out:
# 2022-11-23 16:18:40.999672: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Python Version     :  3.10.0
# TensorFlow Version :  2.11.0

# %%
# below code adapted from:
# https://keras.io/getting_started/faq/#how-can-i-obtain-reproducible-results-using-keras-during-development

# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.
np.random.seed(123)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.
random.seed(123)

# The below set_seed() will make random number generation
# in the TensorFlow backend have a well-defined initial state.
# For further details, see:
# https://www.tensorflow.org/api_docs/python/tf/random/set_seed
tf.random.set_seed(1234)

# %%
# set system parameters
DATASET_PATH  = '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/'
FILE_FORMAT = ''

SAMPLE_RATE   = 32000   # all the samples are converted to bit rate of 32000 (Samples/Second)
MIN_FREQUENCY = 16      # minimum frequency (Hz) for the Fast Fourier Transform related functions
MAX_FREQUENCY = 4096*3  # minimum frequency (Hz) for the Fast Fourier Transform related functions
HOP_LENGTH    = 128     # the number of samples to slide spectrogram window along the audio samples
NUMBER_FFT    = 2048    # the number of FFT to execute within a single spectrogram window
NUMBER_MELS   = 128     # the number of Mel-Spectrogram groups to split the frequency dimension
CLIP_LENGTH   = 5      # only look at 10 seconds of clip at the start of loaded audio file

TARGET_FORMAT = '.mp3'
ACCEPTED_FORMAT = ['.mp3', '.flac', '.aiff', '.mp4', '.m4a', '.wav', '.ogg']

# %%
class raw_file_pre_processing():
    def __init__(self) -> None:
        self.labels = []
        self.directories = {}

    def get_raw_file_paths(self, directory):
        for root, dir, files in os.walk(directory):
            if dir == []:
                tmp_lable = str(root).split("/")[-1]
                tmp_file_dir = []
                for file in files:
                    tmp_file_dir.append(os.path.join(root, file))

                self.directories.update({tmp_lable:tmp_file_dir})

        for key in self.directories:
            print(f'FOUND: {key} -> {len(self.directories[key])}')

# %%
data_preprocessing_pipeline = raw_file_pre_processing()

data_preprocessing_pipeline.get_raw_file_paths(DATASET_PATH)
# Out:
# FOUND: jabwar -> ['/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC536945.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC301222.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC332824.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC332819.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC329587.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC190838.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC463789.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC536946.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC190437.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC660617.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC409023.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC536947.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC605316.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC410204.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC451338.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC465465.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC576627.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC372140.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC539050.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC235544.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC144404.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC423734.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC198427.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC528853.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC479567.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC191038.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC385194.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC122542.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC236038.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/jabwar/XC19120 ...
# FOUND: wiltur -> ['/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC217291.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC104533.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC153735.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC134744.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC538558.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC104532.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC334313.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC508128.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC153736.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC640713.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC153737.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC134155.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC655928.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC428566.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC334314.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC417806.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC365158.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC618595.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC152604.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC419815.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC30896.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC136045.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC317966.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC451611.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC481141.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC586564.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC30895.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC586566.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC561706.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/wiltur/XC370486. ...
# FOUND: sheowl -> ['/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC616344.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC666502.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC666516.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC465266.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC216039.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC664664.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC295898.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC666503.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC608379.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC410559.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC582788.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC365412.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC342126.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC666501.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC146475.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC656164.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC413537.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC246621.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC322371.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC318984.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC142830.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC528759.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC344157.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC48752.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC343174.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC586517.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC608382.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC666498.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC618152.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/sheowl/XC616143 ...
# FOUND: brant -> ['/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC294371.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC337579.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC440582.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC163344.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC500762.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC294370.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC167726.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC397451.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC597408.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC511686.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC163352.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC541304.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC519620.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC358369.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC143518.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC530113.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC500761.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC397450.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC437687.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC295121.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC408265.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC163342.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC402991.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC408264.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC453499.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC594893.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC437686.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC540354.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC161421.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/brant/XC522921.ogg', '/Users/stephankokkas/D ...
# FOUND: spodov -> ['/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC464795.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC518845.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC497557.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC74457.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC612056.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC153052.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC477307.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC40042.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC312465.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC124409.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC510573.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC293596.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC31444.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC181467.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC477310.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC627819.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC443310.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC545211.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC565937.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC207655.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC190962.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC293551.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC443311.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC348751.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC214010.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC510575.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC400389.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC31443.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC443312.ogg', '/Users/stephankokkas/Documents/GitHub/Bioacoustics-Classification-Tool/src/audio-to-png-pipeline/birdclef2022/spodov/XC240369.og ...
