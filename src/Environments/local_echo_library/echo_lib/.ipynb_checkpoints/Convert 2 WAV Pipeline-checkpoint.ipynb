# %% [markdown]
# # This notebook scans all directories in an input bucket and converts all files to wav
#
# This occurs inplace and deletes the original file and replaces it with a .wav file, It overwrites an existing file by the same name.
#
# It expects input of a "bucket" folder, consisting of subfolders named as species, and the audio files within.
# If converting a single folder, create a parent folder to put it into.
#
# Audio file formats are
# - .mp3
# - .flac
# - .wav
#
# Video file inputs are
# - .mp4
# - .m4a

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import pandas as pd
import numpy as np
import librosa, librosa.display
import pathlib
import glob
import pathlib
import subprocess

# %%
# input parameters

source_folder ="/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket"

# options are currently ".mp3" or ".wav" (there is scope to add more)
output_file_type = ".wav"
# output_file_type = ".wav"

# %% [markdown]
# # TODO:
# ## Make sure to use try / except

# %%
# check if there are multiple folders in source_folder



source_folder ="/Volumes/UGREEN Samsung SSD/project echo audio/test data/test_1"

# %%
# import folders as pathlib list

folder_paths = pathlib.Path(source_folder).glob("**/*") #generator object
folders = [x for x in folder_paths if x.is_dir()]
for folder in folders:
    print(folder)
# Out:
# /Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_

# %%
# audio file paths

for folder in folders:
    
    audio_paths = pathlib.Path(folder).glob("**/*") #generator object
    audio_files = [x for x in audio_paths if x.is_file()] #PosixPath list

print(audio_files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # audio file paths
# ----> 3 for folder in folders:
#       5     audio_paths = pathlib.Path(folder).glob("**/*") #generator object
#       6     audio_files = [x for x in audio_paths if x.is_file()] #PosixPath list
#
# NameError: name 'folders' is not defined

# %%
audio_files = pathlib.Path(folder_files).glob("**/*") #generator object
audio_files = [x for x in folder_files if x.is_file()] #PosixPath list
audio_files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 audio_files = pathlib.Path(folder_files).glob("**/*") #generator object
#       2 audio_files = [x for x in folder_files if x.is_file()] #PosixPath list
#       3 audio_files
#
# NameError: name 'folder_files' is not defined

# %%
# input the bucket directory here
# must be a parent directory with folders of audio files
bucket ="/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket"





species_bucket = os.listdir(bucket)
species_bucket
# Out:
# ['.DS_Store', 'eBird_testing Yamnet segmenting_mp3_']

# %%
# writes creates a dataframe of species (folder names)

check .exists()


species_bucket = pd.DataFrame(species_bucket, columns = ["animal species"])
species_bucket.index = np.arange(1, len(species_bucket) + 1)
species_bucket = species_bucket.sort_values("animal species")
species_bucket = species_bucket.iloc[1:]
species_bucket.index = np.arange(1, len(species_bucket) + 1)
print("files: {}".format(len(species_bucket)))
species_bucket.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # writes creates a dataframe of species (folder names)
# ----> 3 check .exists()
#       6 species_bucket = pd.DataFrame(species_bucket, columns = ["animal species"])
#       7 species_bucket.index = np.arange(1, len(species_bucket) + 1)
#
# NameError: name 'check' is not defined

# %%
## extract species as dataframe
# function to crearte a dataframe of all species (folders) in the bucket, listed alphabetically
def species_as_dataframe(folder_filepath):
    species_list = os.listdir(folder_filepath)
    species_dataframe = pd.DataFrame(species_list, columns = ["animal species"])
    species_dataframe.index = np.arange(1, len(species_dataframe) + 1)
    species_dataframe = species_dataframe.sort_values("animal species")
    species_dataframe = species_dataframe.iloc[1:]
    species_dataframe.index = np.arange(1, len(species_dataframe) + 1)
    return species_dataframe 

species_as_dataframe(bucket)
# Out:
#                          animal species
# 1  eBird_testing Yamnet segmenting_mp3_

# %%
# function to crearte a dataframe of full directory names of species in the bucket, listed alphabetically

def file_paths_as_df(bucket):  # maybe change to receive the column value too
    bucket_folders = glob.glob(bucket+"/*")
    bucket_folders = pd.DataFrame(bucket_folders, columns = ["animal species folder paths"])
    bucket_folders = bucket_folders.sort_values("animal species folder paths")
    bucket_folders.index = np.arange(1, len(bucket_folders) + 1)
    bucket_folders.head()
    return bucket_folders
bucket_file_paths_as_dataframe = file_paths_as_df(bucket)
bucket_file_paths_as_dataframe
# Out:
#                          animal species folder paths
# 1  /Volumes/UGREEN Samsung SSD/project echo audio...

# %%
# this takes a dataframe and changes it back to list
def file_paths_as_list(bucket_folders_dataframe):
    bucket_folders_list = bucket_folders_dataframe.values.tolist()
    bucket_folders_list = list(np.concatenate(bucket_folders_list).flat)
    bucket_folders_list[0:1]
    return bucket_folders_list

# %%
bucket_file_paths_as_list = file_paths_as_list(file_paths_as_df(bucket))
bucket_file_paths_as_list
# Out:
# ['/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_']

# %%
# this creates a .wav version of a file past to it
# it will save with the same name
# it will overwrite if an existing .wav file exists with the same name

def convert_individual_file(file_path):
    parent_path = pathlib.PurePath(file_path).parent    
    file_name = pathlib.Path(file_path).stem   
    output_file_path = str(parent_path) + "/" + file_name + ".wav"
    # write the new wav file forcing overwrite 
    subprocess.call(['ffmpeg', '-y', '-i', file_path,
                 output_file_path])
    return

# %%
# this function checks the filepath passed to it and checks the filetype
# if it is one of the listed filetypes ot be converted, it will make a new version 
# as a .wav and delete the original

def check_for_conversion(i, species_filepath):  
    audio_file_paths = glob.glob(species_filepath+"/*")

    for i in range(len(audio_file_paths)):
        if pathlib.Path(audio_file_paths[i]).suffix == ".mp3":
            convert_individual_file(audio_file_paths[i]) # save a new copy as wav in this directory
            os.remove(audio_file_paths[i])

        elif pathlib.Path(audio_file_paths[i]).suffix == ".flac":
            convert_individual_file(audio_file_paths[i]) # save a new copy as wav in this directory
            os.remove(audio_file_paths[i])

        elif pathlib.Path(audio_file_paths[i]).suffix == ".m4a":
            convert_individual_file(audio_file_paths[i]) # save a new copy as wav in this directory
            os.remove(audio_file_paths[i])

        elif pathlib.Path(audio_file_paths[i]).suffix == ".mp4":
            convert_individual_file(audio_file_paths[i]) # save a new copy as wav in this directory
            os.remove(audio_file_paths[i])
    return

# %%
### working here ###

'''
pathlib.PurePath would work much better here I'm sure ...
'''

def convert_files(bucket_file_path):
    print("Folders scanned")
    print(".........")
    for i in range(len(species_bucket)):
        bucket_species_dataframe = species_as_dataframe(bucket_file_path)
        bucket_file_paths_as_list = file_paths_as_list(file_paths_as_df(bucket_file_path))
        current_species_file_pathame = bucket_file_paths_as_list[i]
        check_for_conversion(i, current_species_file_pathame)
    print(bucket_species_dataframe)
    print(".........")
    print("Conversion Complete")

# %%
convert_files(bucket)
# Out:
# Folders scanned
# .........
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/419833341.wav':
#   Duration: 00:00:07.29, bitrate: 2116 kb/s
#   Stream #0:0: Audio: pcm_s24le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s32 (24 bit), 2116 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s24le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/419833341.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, s32p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     115kB time=00:00:07.28 bitrate= 129.2kbits/s speed= 109x
# video:0kB audio:115kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.214567%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/342736611.wav':
#   Metadata:
#     title           : 201231_12
#     artist          : My Recording
#   Duration: 00:02:49.17, bitrate: 2304 kb/s
#   Stream #0:0: Audio: pcm_s24le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s32 (24 bit), 2304 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s24le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/342736611.mp3':
#   Metadata:
#     TIT2            : 201231_12
#     TPE1            : My Recording
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, s32p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=    2644kB time=00:02:49.15 bitrate= 128.0kbits/s speed=82.6x
# video:0kB audio:2644kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.010380%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/420533031.wav':
#   Metadata:
#     title           : Western bristlebird
#     encoder         : Lavf60.3.100
#   Duration: 00:00:29.38, bitrate: 768 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 1 channels, s16, 768 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/420533031.mp3':
#   Metadata:
#     TIT2            : Western bristlebird
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     230kB time=00:00:29.35 bitrate=  64.2kbits/s speed= 164x
# video:0kB audio:230kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.113946%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/419697951.wav':
#   Metadata:
#     title           : New Recording 14
#     encoder         : Lavf60.3.100
#   Duration: 00:00:14.08, bitrate: 768 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 1 channels, s16, 768 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/419697951.mp3':
#   Metadata:
#     TIT2            : New Recording 14
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     111kB time=00:00:14.06 bitrate=  64.4kbits/s speed= 166x
# video:0kB audio:110kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.233844%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/342107641.wav':
#   Duration: 00:02:16.28, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/342107641.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=    1065kB time=00:02:16.25 bitrate=  64.0kbits/s speed= 190x
# video:0kB audio:1065kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020725%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/418867821.wav':
#   Duration: 00:00:37.43, bitrate: 768 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 1 channels, s16, 768 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/418867821.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     293kB time=00:00:37.41 bitrate=  64.1kbits/s speed= 198x
# video:0kB audio:293kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.078742%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/335218731.wav':
#   Duration: 00:00:20.10, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/335218731.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     315kB time=00:00:20.08 bitrate= 128.4kbits/s speed=  95x
# video:0kB audio:315kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.073252%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/341847361.wav':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Duration: 00:00:36.81, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/341847361.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     576kB time=00:00:36.78 bitrate= 128.2kbits/s speed= 109x
# video:0kB audio:576kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042761%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/341451001.wav':
#   Metadata:
#     title           : New Recording 10
#     encoder         : Lavf60.3.100
#   Duration: 00:00:53.57, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/341451001.mp3':
#   Metadata:
#     TIT2            : New Recording 10
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     419kB time=00:00:53.55 bitrate=  64.1kbits/s speed= 171x
# video:0kB audio:419kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.059231%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/420367571.wav':
#   Duration: 00:00:04.84, bitrate: 2116 kb/s
#   Stream #0:0: Audio: pcm_s24le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s32 (24 bit), 2116 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s24le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/420367571.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, s32p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=      77kB time=00:00:04.83 bitrate= 129.8kbits/s speed= 109x
# video:0kB audio:76kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.322424%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/419485731.wav':
#   Duration: 00:00:04.46, bitrate: 2116 kb/s
#   Stream #0:0: Audio: pcm_s24le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s32 (24 bit), 2116 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s24le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/419485731.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, s32p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=      70kB time=00:00:04.44 bitrate= 129.9kbits/s speed= 105x
# video:0kB audio:70kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.350540%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/337288361.wav':
#   Duration: 00:00:38.73, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 96000 Hz, 1 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/337288361.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     303kB time=00:00:38.71 bitrate=  64.1kbits/s speed= 158x
# video:0kB audio:303kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.076109%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/345929991.wav':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Duration: 00:00:27.98, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/345929991.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     438kB time=00:00:27.95 bitrate= 128.3kbits/s speed= 152x
# video:0kB audio:438kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.056243%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/420749121.wav':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:17.50, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/420749121.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     274kB time=00:00:17.49 bitrate= 128.5kbits/s speed=77.8x
# video:0kB audio:274kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.084074%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/337288411.wav':
#   Duration: 00:00:11.06, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 96000 Hz, 1 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/337288411.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=      87kB time=00:00:11.04 bitrate=  64.4kbits/s speed= 192x
# video:0kB audio:87kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.266053%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/346870391.wav':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Duration: 00:00:03.62, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/346870391.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=      57kB time=00:00:03.60 bitrate= 130.2kbits/s speed= 119x
# video:0kB audio:57kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.404331%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/343592631.wav':
#   Metadata:
#     artist          : Sara Young
#     title           : 210530_09
#     comment         : Male
#   Duration: 00:01:25.21, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 96000 Hz, 1 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/343592631.mp3':
#   Metadata:
#     TPE1            : Sara Young
#     TIT2            : 210530_09
#     comment         : Male
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     666kB time=00:01:25.20 bitrate=  64.1kbits/s speed= 182x
# video:0kB audio:666kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.044429%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/346861471.wav':
#   Duration: 00:00:12.12, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/346861471.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=      95kB time=00:00:12.09 bitrate=  64.4kbits/s speed= 204x
# video:0kB audio:95kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.232570%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/336887391.wav':
#   Duration: 00:00:23.10, bitrate: 768 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 1 channels, s16, 768 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/336887391.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     181kB time=00:00:23.08 bitrate=  64.2kbits/s speed= 176x
# video:0kB audio:181kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.127507%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/343554851.wav':
#   Duration: 00:00:22.76, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/343554851.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     356kB time=00:00:22.75 bitrate= 128.3kbits/s speed=85.9x
# video:0kB audio:356kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.064693%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
# ...
#   Duration: 00:01:52.89, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/342108961.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     882kB time=00:01:52.87 bitrate=  64.0kbits/s speed= 178x
# video:0kB audio:882kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.025016%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/338816931.wav':
#   Metadata:
#     artist          : Sara Young
#     title           : 210516_06
#   Duration: 00:01:22.15, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 96000 Hz, 1 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/338816931.mp3':
#   Metadata:
#     TPE1            : Sara Young
#     TIT2            : 210516_06
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     642kB time=00:01:22.12 bitrate=  64.1kbits/s speed= 189x
# video:0kB audio:642kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042439%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/418189961.wav':
#   Metadata:
#     title           : Spiny-cheeked Honeyeater
#     encoder         : Lavf60.3.100
#   Duration: 00:00:48.94, bitrate: 768 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 1 channels, s16, 768 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/418189961.mp3':
#   Metadata:
#     TIT2            : Spiny-cheeked Honeyeater
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     383kB time=00:00:48.93 bitrate=  64.1kbits/s speed= 177x
# video:0kB audio:383kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.069666%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/419949021.wav':
#   Duration: 00:00:07.24, bitrate: 2116 kb/s
#   Stream #0:0: Audio: pcm_s24le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s32 (24 bit), 2116 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s24le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/419949021.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, s32p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=     114kB time=00:00:07.23 bitrate= 129.2kbits/s speed=80.3x
# video:0kB audio:114kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.216105%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/370047791.wav':
#   Metadata:
#     encoded_by      : WavePad © NCH Software
#     ISRC            : WavePad © NCH Software
#     time_reference  : 0
#   Duration: 00:00:08.99, bitrate: 770 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 1 channels, s16, 768 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/370047791.mp3':
#   Metadata:
#     TENC            : WavePad © NCH Software
#     ISRC            : WavePad © NCH Software
#     time_reference  : 0
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 48000 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=      71kB time=00:00:08.97 bitrate=  64.6kbits/s speed= 152x
# video:0kB audio:70kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.469581%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/341416181.wav':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Duration: 00:00:05.09, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/341416181.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=      80kB time=00:00:05.06 bitrate= 129.7kbits/s speed=75.8x
# video:0kB audio:80kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.307617%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/336255021.wav':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Duration: 00:00:10.92, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/Volumes/UGREEN Samsung SSD/project echo audio/eBird/eBird_Bucket/bucket/eBird_testing Yamnet segmenting_mp3_/336255021.mp3':
#   Metadata:
#     TSSE            : Lavf60.3.100
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, s16p
#     Metadata:
#       encoder         : Lavc60.3.100 libmp3lame
# size=      86kB time=00:00:10.89 bitrate=  64.5kbits/s speed= 171x
# video:0kB audio:86kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.258103%
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 convert_files(bucket)
#
# Cell In[22], line 13, in convert_files(bucket_file_path)
#      11     bucket_species_dataframe = species_as_dataframe(bucket_file_path)
#      12     bucket_file_paths_as_list = file_paths_as_list(file_paths_as_df(bucket_file_path))
# ---> 13     current_species_file_pathame = bucket_file_paths_as_list[i]
#      14     check_for_conversion(i, current_species_file_pathame)
#      15 print(bucket_species_dataframe)
#
# IndexError: list index out of range

# %%
# run a second time to generate a clean output
convert_files(bucket)
